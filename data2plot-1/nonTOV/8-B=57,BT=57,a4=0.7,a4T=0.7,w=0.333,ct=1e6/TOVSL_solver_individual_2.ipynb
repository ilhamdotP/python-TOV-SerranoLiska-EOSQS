# %%
# deleting profile and radmass files
import os

if os.path.exists('profileSL.dat'):
    os.remove('profileSL.dat')

if os.path.exists('radmassSL.dat'):
    os.remove('radmassSL.dat')

# %%
# source: https://www.codesansar.com/numerical-methods/
#         runge-kutta-fourth-order-rk4-python-program.htm

import cmath #To help us out with the complex square root
import numpy as np #For the arrays
import matplotlib.pyplot as plt #Visualization

# deleting profile and radmass files
# os.remove("radmass.txt")
# os.remove("profile.txt")

# some constants
GS = 1.325 * 10**(-12) # Newton constant in fm^3 / MeV m^2
MSS = 1.1155 * 10**(15) # Sun's mass in MeV m^3 / fm^3
PI = np.pi 
HC = 197.327 # hc=1=197.327 MeV fm
KN = 8*PI*GS

# constants in eden
B = 57 # MeV
w = 1/3. # speed of sound
a4 = 0.7 # don't know, dimensionless
ms = 100 # quark mass in MeV

# additional constants for tangential pressure
BT = 57 # MeV
a4t = 0.7 # don't know, dimensionless

# constants for SL model
ctilde = 1.e6 # meter^2

# masalah satuan 
alpha = ms**2/(3*PI*np.sqrt(a4))*HC**(-1.5)
beta = ms**4/(12*PI**2)*(1-1/a4)*HC**(-3)
gamma = 8*PI/(3*ms**2*np.sqrt(a4))*HC**(1.5)
kappa = 3/(1-1/a4)

alphat = ms**2/(3*PI*np.sqrt(a4t))*HC**(-1.5)
betat = ms**4/(12*PI**2)*(1-1/a4t)*HC**(-3)
gammat = 8*PI/(3*ms**2*np.sqrt(a4t))*HC**(1.5)
kappat = 3/(1-1/a4t)

# %%
# define energy density as function of pressure

def eden(P):
    sqdoe = alpha**2 + 4*w*P + 12*w**2*B
    doeden = alpha**2/(2*w**2) + alpha/(2*w**2)*np.sqrt(sqdoe)
    lgPt = gamma*np.sqrt(P/w + 3*B + doeden)
    Ptilde = P - beta*(1+kappa*np.log(lgPt))
    sqde = alpha**2 + 4*w*Ptilde + 12*w**2*B
    deden = alpha**2/(2*w**2) + alpha/(2*w**2)*np.sqrt(sqde)
    # print("cek eden: ",sqdoe,doeden,lgPt,Ptilde,sqde,deden)
    return P/w + 4*B + deden

def dedP(P):
    dP = 0.00001
    x1 = P-2*dP
    x2 = P-dP
    x3 = P+dP
    x4 = P+2*dP
    dedP = eden(x1) - 8*eden(x2) + 8*eden(x3) - eden(x4)
    dedP = dedP/(12*dP)
    return dedP

# define tangential pressure

def fpt(ed,PCC):
    fpt = PCC + w*(ed-4*BT) - alphat*np.sqrt(ed-BT)
    fpt = fpt + betat*(1+kappat*np.log(gammat*np.sqrt(ed-BT)))
    fpt = fpt - w*(eden(PCC)-4*BT) + alphat*np.sqrt(eden(PCC)-BT)
    fpt = fpt - betat*(1+kappat*np.log(gammat*np.sqrt(eden(PCC)-BT)))
    return fpt

def dPTde(ed):
    return w-(1/2)*alphat/np.sqrt(ed-BT)+(1/2)*betat*kappat/(ed-BT)

# define sigma

def sig(P,PCC):
    ed = eden(P)
    Ptan = fpt(ed,PCC)
    sig = P - Ptan
    return sig

def dsdP(P,PCC):
    dP = 0.00001
    x1 = P-2*dP
    x2 = P-dP
    x3 = P+dP
    x4 = P+2*dP
    dsdP = sig(x1,PCC) - 8*sig(x2,PCC) + 8*sig(x3,PCC) - sig(x4,PCC)
    dsdP = dsdP/(12*dP)
    return dsdP


# the TOV SL equation

def b1(r,P,m,b,Lambda):
    Pcorr0 = Lambda - (1/2)*(eden(P)+P)**2 - 2*sig(P,PCC)*(eden(P)+P) 
    Pcorr = P - (KN/4)*ctilde*Pcorr0
    return (4*PI*r**3*Pcorr+MSS*m)*2*GS/(2*r*(r-2*GS*MSS*m))*2*b

def P1(r,P,m,b,Lambda):
    return -(eden(P)+P) * b1(r,P,m,b,Lambda)/(2*b) -2*sig(P,PCC)/r

def m1(r,P,m,b,Lambda):
    edencorr0 = Lambda - (3/2)*(eden(P)+P)**2 + 2*sig(P,PCC)*(eden(P)+P) 
    edencorr = eden(P) + (KN/4)*ctilde*edencorr0
    return 4*PI*r**2*edencorr/MSS

def L1(r,P,m,b,Lambda):
    ed = eden(P)
    dsde=1/dedP(P)-dPTde(ed)
    sigprime = dsdP(P,PCC)*P1(r,P,m,b,Lambda)
    sigprime = sigprime + dsde*dedP(P)*P1(r,P,m,b,Lambda)
    Lambda1 = P1(r,P,m,b,Lambda)*(eden(P)+P-2*sig(P,PCC))*(1-dedP(P))
    Lambda1 = Lambda1 + 8*sig(P,PCC)/r*(eden(P)+P-sig(P,PCC))
    Lambda1 = Lambda1 + 2*sigprime*(eden(P)+P)
    return Lambda1

# %%
# define the Runge-Kutta 4th order for the problem
# if we want to print the profile, set profile=1
# if we not, set profile=0
def RungeKutta(rCC,bCC,LCC,PCC,MCC,h,profile):
    # input initial values
    r0 = rCC
    b0 = bCC
    P0 = PCC
    m0 = MCC
    L0 = LCC
    while (P0 > 0.):
        if profile == 1:
            f0 = 1-2*GS*MSS*m0/r0
            print(r0/1000, b0, P0, m0, L0/1.e+6, f0, file=open('profileSL.dat', 'a'))
        # calculate k1
        r01 = r0
        b01 = b0
        P01 = P0
        m01 = m0
        L01 = L0
        k1_b = h * b1(r01,P01,m01,b01,L01)
        k1_P = h * P1(r01,P01,m01,b01,L01)
        k1_m = h * m1(r01,P01,m01,b01,L01)
        k1_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k2
        r01 = r0 + h/2
        b01 = b0 + k1_b/2
        P01 = P0 + k1_P/2
        m01 = m0 + k1_m/2
        L01 = L0 + k1_L/2
        k2_b = h * b1(r01,P01,m01,b01,L01)
        k2_P = h * P1(r01,P01,m01,b01,L01)
        k2_m = h * m1(r01,P01,m01,b01,L01)
        k2_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k3
        r01 = r0 + h/2
        b01 = b0 + k2_b/2
        P01 = P0 + k2_P/2
        m01 = m0 + k2_m/2
        L01 = L0 + k2_L/2
        k3_b = h * b1(r01,P01,m01,b01,L01)
        k3_P = h * P1(r01,P01,m01,b01,L01)
        k3_m = h * m1(r01,P01,m01,b01,L01)
        k3_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k4
        r01 = r0 + h
        b01 = b0 + k3_b
        P01 = P0 + k3_P
        m01 = m0 + k3_m
        L01 = L0 + k3_L
        k4_b = h * b1(r01,P01,m01,b01,L01)
        k4_P = h * P1(r01,P01,m01,b01,L01)
        k4_m = h * m1(r01,P01,m01,b01,L01)
        k4_L = h * L1(r01,P01,m01,b01,L01)
        # calculate the next r0, P0, m0, and b0
        r0 = r0 + h
        b0 = b0 + (k1_b+2*k2_b+2*k3_b+k4_b)/6
        P0 = P0 + (k1_P+2*k2_P+2*k3_P+k4_P)/6
        m0 = m0 + (k1_m+2*k2_m+2*k3_m+k4_m)/6
        L0 = L0 + (k1_L+2*k2_L+2*k3_L+k4_L)/6
        f0 = 1-2*GS*MSS*m0/r0
        # print(P0)
    if profile == 1:
        f0 = 1-2*GS*MSS*m0/r0
        print(r0/1000, b0, P0, m0, L0/1.e+6, f0, file=open('profileSL.dat', 'a'))
    # the results at the surface
    output = np.array([r0,b0,P0,m0,L0,f0])
    return output
# define for a single PCC

def single_PCC(x,radmassdata,profile):
    # define initial parameters
    rCC = 1.*10**(-12) # radius near center in m--the starting point
    rmax = 100000. # radius at far distances in m
    PCC = x # pressure at the center in MeV / fm^3
    MCC = (4*PI/3)*eden(PCC)*rCC**3/MSS # Mass at the center in MeV m^3 / fm^3
    bCC = 1-2*GS*MSS*MCC/rCC # metric function b(r) at the center
    LCC = 1.*10**(-12) # Lambda function at center

    h = 10. # h-step

    # calculate the surface values
    output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
    # print(output)

    # at the surface, b = 1-2Gm/r, which is different to the result
    rSurface=output[0]
    bSurface=output[1]
    mSurface=output[3]
    bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface

    # So, we redefine bCC as follows
    bCorrection=bSurfaceTarget/bSurface
    # print("cek bCC ",abs(bCorrection-1))

    # if abs(LSurface) not near 0, then recalculate
    LSurface=output[4]
    print(PCC, rSurface, mSurface, GS*MSS*mSurface/rSurface, bCorrection, LSurface)

    # if abs(bCorrection) not near 1, then recalculate
    while (abs(bCorrection-1)>10**(-3)):
        while (abs(LSurface)>10**(-1)):
            print("abs(LSurface)>10**(-1)")
            if ctilde==0:
                break
            LCC = LCC - LSurface
            output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
            LSurface=output[4]
            # print("cek LCC ",(LSurface))
            # print(output)
        print("abs(bCorrection-1)>10**(-3)")
        bCC=bCC*bCorrection
        output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
        rSurface=output[0]
        bSurface=output[1]
        mSurface=output[3]
        bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface
        bCorrection=bSurfaceTarget/bSurface

    rSurface=output[0]
    bSurface=output[1]
    mSurface=output[3]
    bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface
    bCorrection=bSurfaceTarget/bSurface
    LSurface=output[4]
    print(PCC, rSurface, mSurface, GS*MSS*mSurface/rSurface, bCorrection, LSurface)

    if profile == 1:
        output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,profile)
        # print(output)
    if radmassdata == 1:
        print(PCC, (eden(PCC)/1000), (rSurface/1000), mSurface, 
            2*GS*MSS*mSurface/rSurface, LCC/1.e+6, 0.5*np.log(bCC),
            file=open('radmassSL.dat', 'a'))

    output2=np.array([PCC, (eden(PCC)/1000), (rSurface/1000), mSurface, GS*MSS*mSurface/rSurface])
    return output2

# %%
# this is for multiple PCC
for x in range(5, 501, 5):
    PCC=x
    if PCC==500:
        single_PCC(PCC,1,1)
    else:
        single_PCC(PCC,1,0)
# Out:
# 5 5050.000000000001 0.1219118908982242 0.03568125672148197 0.893206131155168 2807.7528631367622
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 5 5050.000000000001 0.12189984054485713 0.03567772981570677 1.0000011711854402 6.528455096699304e-05
# 10 6680.000000000001 0.28871204995151317 0.06388132283386369 0.8093238191769533 5837.231948882855
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 10 6670.000000000001 0.28741714701419496 0.06369015313792999 1.0006354523497432 -0.0033911027057733634
# 15 7700.000000000001 0.45185146109750496 0.08673420830284458 0.7416790293371353 9070.422923249878
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 15 7690.000000000001 0.4500620998457689 0.0865030768401548 1.0007869474654414 -0.0050566101534705865
# 20 8410.0 0.6008903267054577 0.10560504592840878 0.6860287043981983 12504.435882623842
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 20 8410.0 0.6006153105675026 0.1055567124961849 1.0000496868311424 0.0018810868514442802
# 25 8930.0 0.7335254146125451 0.12140851847708728 0.6395413322776806 16134.428946601907
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 25 8930.0 0.7330923074679664 0.12133683330338009 1.0000861628105995 0.002925708119324355
# 30 9330.0 0.8518858239675444 0.1349538256744297 0.5998174152575686 20027.66288823918
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 30 9330.0 0.8512633291575707 0.13485521145441937 1.0001339526161417 0.004101723730698836
# 35 9640.0 0.9561324801120588 0.1465974751632393 0.5657027208426243 24107.98747541599
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 35 9640.0 0.9552960715787125 0.14646923416971172 1.0001922633979354 0.005351485506452036
# 40 9890.0 1.0495018730745798 0.1568456142289655 0.5357395326888463 28413.56548622472
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 40 9880.0 1.0457218340034622 0.15643887502286355 1.0 -0.008233069965200457
# 45 10090.0 1.132183202335259 0.1658482883965907 0.5094135834252358 32882.72441136154
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 45 10080.0 1.1280369764593738 0.16540485640809238 1.0000000000000036 -0.008140965658974153
# 50 10250.0 1.2047955621270836 0.17373005079584478 0.4863584858910751 37645.50890024844
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 50 10240.0 1.2002836398765993 0.17324845999747157 1.000000000000001 -0.007877534102213701
# 55 10380.0 1.2692115892729467 0.18072662084585864 0.465880247813073 42668.831817817496
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 55 10370.0 1.2643321349884036 0.18020542989083144 1.0000000000000078 -0.007482044353629647
# 60 10490.0 1.3284257665146515 0.18717474727120104 0.446994289509666 47674.00646461428
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 60 10480.0 1.3231835952488415 0.1866140241567375 0.9999999999999784 -0.007070898611758025
# 65 10580.0 1.3811131432388355 0.19294300732040356 0.4300852230621493 52979.91944907865
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 65 10570.0 1.3755031404503266 0.1923410806956811 0.9999999999999816 -0.006557664247331729
# 70 10650.0 1.4270503388968014 0.1980501328898761 0.41503868904004215 58528.47988067688
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 70 10640.0 1.421073025968164 0.1974059419755094 0.9999999999999927 -0.005991722821605094
# 75 10710.0 1.468840869774147 0.2027079259625402 0.40134330257845074 64518.279241370146
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 75 10700.0 1.462478895968439 0.20201856553270572 1.0000000000000004 -0.005305310541452002
# 80 10760.0 1.507654966697922 0.20709763734579734 0.38837984260969793 70281.9864524488
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 80 10750.0 1.5009245171580494 0.20636490428176651 1.0000000000000007 -0.004718946040100036
# 85 10800.0 1.5415402882886615 0.21096799572698632 0.3769491375570562 76821.68394601114
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 85 10790.0 1.5344110136163345 0.21018693406283157 0.9999999999999968 -0.003947645720508319
# 90 10830.0 1.5722583653264715 0.21457588399272612 0.3661934615307031 83099.36009145694
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 90 10820.0 1.5647529940675733 0.21374894671618766 0.9999999999999866 -0.0033200081344730847
# 95 10860.0 1.602229331623424 0.21806215798704934 0.3558752123772022 89609.16381243031
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 95 10850.0 1.5943331553219275 0.2171874830469247 1.0000000000000042 -0.0026393122602854646
# 100 10880.0 1.6280157541125504 0.22116436904128015 0.34660344492159667 96428.00692822495
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 100 10870.0 1.6197261594972558 0.22024066269254136 1.0000000000001081 -0.00196718682882846
# 105 10900.0 1.653093579958817 0.22415911029251187 0.3377062512531121 103479.14048526133
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 105 10890.0 1.6443969641343705 0.22318460770218126 1.0000000000000169 -0.0012406872475239084
# 110 10910.0 1.674181436227816 0.22681053570564347 0.3297040281168116 110710.25261352639
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 110 10900.0 1.6650850284926533 0.22578514796336782 0.9999999999999901 -0.000521420384295368
# 115 10920.0 1.6947507454809811 0.22938691895364882 0.3219592034660478 118028.92827197413
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 115 10910.0 1.6852501390340455 0.22831007354468677 1.000000000000006 0.00011436597601033327
# 120 10920.0 1.7110592287640674 0.2315942953145027 0.31517849748481824 125798.13528536107
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 120 10910.0 1.7011510878183154 0.23046426223292968 1.000000000000096 0.000852560166080707
# 125 10930.0 1.7300818963757152 0.23395479605804395 0.3081508516929678 133849.6420290567
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 125 10920.0 1.719732079414933 0.23276817796046229 1.0000000000000013 0.0015293870240782326
# 130 10930.0 1.744942143820832 0.2359643114270432 0.30202193232323266 142377.3305916657
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 130 10920.0 1.7341477271516343 0.2347193563433959 1.000000000000093 0.0023116362513562194
# 135 10930.0 1.760160888060845 0.2380223054517137 0.29573695345799705 150069.1051198608
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 135 10910.0 1.7456721497925964 0.23649577452787113 1.00000000000004 -0.019775816823624837
# 140 10920.0 1.7712332058963176 0.23973892853113352 0.29031179986685773 158208.95296099986
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 140 10910.0 1.7596451104833197 0.2383887681013739 0.9999999999991214 0.003445396352120156
# 145 10920.0 1.7850955419236625 0.24161521538882735 0.2846129350188631 166605.95295239147
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 145 10910.0 1.7730770920059162 0.24020847226175013 1.0000000000000207 0.004012884114253268
# 150 10910.0 1.7942426267124436 0.24307588326118174 0.2800152001900111 176469.1535373475
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 150 10900.0 1.781744840398759 0.2416041917009982 0.9999999999999315 0.004860066930845619
# 155 10910.0 1.8075796885440376 0.24488272813074313 0.27453229795302847 184621.26762624862
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 155 10890.0 1.7913861274009257 0.24313460727992148 0.999999999999742 -0.017160593487361098
# 160 10900.0 1.8164934884898245 0.24631610041227325 0.2700110233435343 193921.36354267062
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 160 10890.0 1.8031414594756492 0.24473009135993934 1.0 0.005902690371563324
# 165 10890.0 1.8244033585419719 0.24761584747942875 0.26592337149329237 204494.44693211195
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 165 10880.0 1.8105466698573505 0.24596101778945617 1.0000000000002542 0.006754431538993799
# 170 10880.0 1.8329032880107414 0.24899814278981391 0.26155294955484654 213520.68755513837
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 170 10870.0 1.8186277803857909 0.2472861138870251 0.9999999999999412 0.007213050850964464
# 175 10870.0 1.8402732125556425 0.2502293301198445 0.2576753055316132 224202.86983675673
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 175 10860.0 1.8254964795498776 0.24844864207115117 1.0000000000000633 0.007939211909992139
# 180 10860.0 1.847657028661247 0.2514646754603957 0.25377335567381687 234374.4236212127
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 180 10850.0 1.832410382131529 0.24961947098430684 1.0000000000000224 0.008589736073552956
# 185 10850.0 1.8548615802610269 0.252677877689867 0.24993346873896602 244372.96594602044
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 185 10840.0 1.8391585059158024 0.25076985610586044 0.9999999999999939 0.00897860722884758
# 190 10840.0 1.8614063344083909 0.2538033547041643 0.24637775306710857 255349.98309032095
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 190 10820.0 1.8419594917915996 0.25161600761080644 0.9999999999998944 -0.012256013137125876
# 195 10830.0 1.8681068336155944 0.2549521656592898 0.24272873996968394 265354.71444547793
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 195 10810.0 1.8482194807473198 0.2527046901734566 0.999999999999532 -0.011718874559562664
# 200 10810.0 1.8709226979883076 0.2558088720839864 0.2397807498603417 276288.9175844122
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 200 10800.0 1.8538162869230195 0.2537046287206465 0.9999999999999963 0.010734547126517668
# 205 10800.0 1.876447179852401 0.2568017869065827 0.23664012319924396 288324.711257884
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 205 10790.0 1.8587989056952927 0.2546222880052461 0.9999999999997761 0.011310188670293542
# 210 10790.0 1.8821246237763831 0.25781749523770947 0.23340578943947327 299333.61064413126
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 210 10770.0 1.8607812039936984 0.25536716794780273 0.999999999999881 -0.009692589371226745
# 215 10780.0 1.8875296092647516 0.25879773143354823 0.23027920096041837 310536.122478346
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 215 10760.0 1.8657040247416419 0.25628071677221875 0.9999999999998929 -0.009092380720176152
# 220 10760.0 1.889184976770789 0.2595061561434809 0.22779330587658497 322741.4920244425
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 220 10750.0 1.870069988351924 0.2571194018984843 0.9999999999999222 0.012943547139130374
# 225 10750.0 1.8938604587050945 0.2603903979286819 0.22497645550917159 335235.73817247467
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 225 10730.0 1.8710144341821764 0.25772875086323743 0.9999999999995521 -0.007794247115640474
# 230 10740.0 1.8984309488261604 0.2612618373860005 0.22218942790919533 347500.5102369794
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 230 10720.0 1.8750647206497957 0.2585276093327819 1.0000000000001423 -0.00723064085687497
# 235 10720.0 1.8994508074488603 0.26188988085957965 0.2199492594353556 360367.05320989375
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 235 10710.0 1.878758196669681 0.2592787178440862 1.000000000000257 0.014554769212210772
# 240 10710.0 1.903708520124952 0.26272199643456423 0.21727193680634427 372586.3964374547
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 240 10690.0 1.8793390293510195 0.2598441123100474 0.9999999999999972 -0.005859443390477281
# 245 10700.0 1.9076560622343575 0.26351282215744987 0.21472903360053558 385473.99514364573
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 245 10680.0 1.8827512876195767 0.2605596447823052 0.9999999999988015 -0.00521674101517533
# 250 10680.0 1.9084020263852943 0.26410952809676536 0.21255501420420356 397533.4774152588
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 250 10660.0 1.8830610056543262 0.2610914428841281 1.0000000000009917 -0.004954014448216526
# 255 10670.0 1.9116013481344725 0.26480023220180926 0.21035579400591597 412785.64791181573
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 255 10650.0 1.8856196247887753 0.261691691659506 0.9999999999999241 -0.003939092429192215
# 260 10650.0 1.9120872479297588 0.26536494419830803 0.20826863165621343 424743.42191917653
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 260 10640.0 1.8888165763069917 0.2623817415792617 1.0000000000002573 0.016881181143219237
# 265 10640.0 1.9151504561991044 0.2660398677071789 0.20609735636677418 439464.82292802556
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 265 10620.0 1.888148832715918 0.26278293600144564 1.000000000000002 -0.0027271914637196915
# 270 10630.0 1.9180651380692737 0.26669540936115366 0.20398518475528202 454424.02695646626
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 270 10610.0 1.8904548069430056 0.26335184700443187 0.9999999999998374 -0.002159246278012006
# 275 10610.0 1.9178249048683993 0.26716466803293365 0.20221934383075574 468505.82699957327
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 275 10590.0 1.8897143992579435 0.2637458684035139 1.0000000000000295 -0.0017678245679206839
# 280 10600.0 1.9212071698009754 0.26788832473912344 0.19979102394259765 478625.57676950336
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 280 10580.0 1.8927326895559096 0.26441681404910133 0.9999999999999923 -0.0013457819687374695
# 285 10590.0 1.9232489807590536 0.2684262620773049 0.1981020933201824 497428.58989087807
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 285 10570.0 1.8939982238677915 0.2648439356490057 1.0000000000007025 -0.0005553097598749446
# 290 10570.0 1.9228760066438662 0.2688820099971507 0.19633282523660556 509946.95232213783
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 290 10550.0 1.8932203639575664 0.265237032577529 1.000000000000048 -9.662259277831708e-05
# 295 10560.0 1.925237813915167 0.2694672050553634 0.1944115771942828 524892.9865552129
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 295 10540.0 1.895002706709336 0.26573862078917454 1.0000000000000482 0.0005003726606958026
# 300 10540.0 1.924336981411382 0.2698522031463781 0.1929028214777898 539973.1740175489
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 300 10520.0 1.893589252849675 0.2660452400483651 1.0000000000013272 0.0010495574099280702
# 305 10530.0 1.9264542100920659 0.270405656652322 0.19107798939826826 555331.0697956948
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 305 10510.0 1.895119328950503 0.26651355234668683 0.9999999999999563 0.0017097851428076183
# 310 10520.0 1.9284532039187263 0.27094355060713154 0.18930025465628178 570894.8699362666
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 310 10500.0 1.8965266169568036 0.2669654723438372 0.999999999996348 0.002291476417170202
# 315 10500.0 1.9272225493078032 0.27128639987833636 0.18792115456551953 586591.6133080492
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 315 10480.0 1.8947761053612948 0.2672280665866359 1.000000000000338 0.0029385317128287625
# 320 10490.0 1.929004326637534 0.27179606600882017 0.1862295203883505 602566.7871063156
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 320 10470.0 1.8959589201652336 0.26765027530694563 1.0000000000027844 0.003255567396507786
# 325 10480.0 1.9306807209312955 0.2722918421816306 0.18458009409559284 618747.6320799784
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 325 10460.0 1.8970319895489178 0.2680577838673908 1.0000000000000053 0.0036459202851233385
# 330 10470.0 1.9322556647640017 0.2727742437544052 0.18297137312873768 635134.0764076561
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 330 10440.0 1.8949830007783615 0.2682812200203972 1.0000000000000675 -0.014557480877456896
# 335 10450.0 1.930459112532022 0.2730421971807701 0.18187347727109557 654110.3506396352
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 335 10430.0 1.895561819851478 0.2686204653220257 1.0000000000003377 0.005308484063746732
# 340 10440.0 1.9320299769645701 0.27352612615687455 0.18021013702286007 668449.3567969151
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 340 10420.0 1.896630409705589 0.2690298338949351 0.9999999999986052 0.0055160929579045614
# 345 10430.0 1.9332460560334743 0.2739607063801127 0.17877387009071075 686711.8039105363
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 345 10400.0 1.8941772555770107 0.2691985591721063 0.9999999999998942 -0.01246287954171521
# 350 10420.0 1.934461047151693 0.2743959664087783 0.17731013118056307 703935.2237571165
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 350 10390.0 1.8947765858716168 0.26954291126469865 1.0000000000001632 -0.012249289655372309
# 355 10400.0 1.9326707646249486 0.27466921781436027 0.17609621306473555 718708.144335402
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 355 10380.0 1.895551359985263 0.26991290878942364 1.000000000000052 0.007275346720859943
# 360 10390.0 1.9335067851254417 0.2750525057670688 0.17487179246607146 740228.9176906083
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 360 10370.0 1.8955844658054022 0.2701779098242866 1.0000000000002776 0.007799346298327237
# 365 10380.0 1.9346861967395332 0.27548542866217796 0.1733357750636308 754119.3857264164
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 365 10350.0 1.8933426057121368 0.2703798426657248 0.9999999999999991 -0.010233090821643032
# 370 10360.0 1.9325275635418222 0.275709286553904 0.17232832129886774 772056.8884262118
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 370 10340.0 1.893606935819923 0.2706791161897426 0.9999999999985871 0.008695504576948565
# 375 10350.0 1.933234238243836 0.27607658941143215 0.1711294524291465 792979.0330428802
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 375 10330.0 1.8935568888993235 0.27093398743238467 0.9999999999966218 0.009445582099075978
# 380 10340.0 1.933940444584304 0.27644453577004574 0.16990249982708544 812800.8981822962
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 380 10320.0 1.893560734971355 0.27119707120302555 0.9999999999952972 0.010577197716543196
# 385 10330.0 1.9346381385472595 0.2768119765443412 0.168650155870772 831475.4267901276
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 385 10300.0 1.8906756962294 0.2713096678995787 1.0000000000002744 -0.007951335256137781
# 390 10320.0 1.935368722926098 0.2771848400011514 0.16732509459907538 847558.2168104548
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 390 10290.0 1.8908850868555915 0.2716034078292829 1.000000000005263 -0.007551774899070551
# 395 10300.0 1.9329507981637615 0.2773760937224243 0.16639502136655362 865121.560717457
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 395 10280.0 1.8909085319473626 0.2718709843665515 0.9999999999965463 0.011368983327784576
# 400 10290.0 1.9333668418725425 0.27770541239496477 0.16531878697121102 887222.2276439252
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 400 10270.0 1.8905477342761494 0.27208378255113763 1.000000000001323 0.012016627491817644
# 405 10280.0 1.9338165579694961 0.2780402131128248 0.1641694310042863 906700.8790927248
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 405 10260.0 1.890339250821643 0.2723189376643561 1.0000000000001024 0.012748410229576734
# 410 10270.0 1.9342464630843113 0.27837281467195496 0.16299827690651839 924924.6319162034
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 410 10240.0 1.887268330647581 0.2724075552011253 0.9999999999996252 -0.0046251053253456575
# 415 10260.0 1.9345809319554563 0.2786923162003033 0.16189728494598318 944797.5159754712
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 415 10230.0 1.886944936920115 0.2726271140960962 1.0000000000000027 -0.004520348726799739
# 420 10250.0 1.9348621272374378 0.27900475915967843 0.16081889023763296 964875.1562471268
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 420 10220.0 1.886564956097169 0.27283891891364664 0.9999999999970218 -0.0032128670461588626
# 425 10240.0 1.935033863881649 0.279302013143259 0.1598484187961072 988169.5119074424
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 425 10210.0 1.8859446579400025 0.2730163493986284 1.00000000000083 -0.0028823058310507577
# 430 10230.0 1.9352980114058014 0.2796131998566179 0.1586851841062427 1004123.6406455891
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 430 10200.0 1.8857329345020486 0.2732533325665756 1.0000000000067528 -0.002527500288422857
# 435 10220.0 1.9353799144607309 0.27989863897453543 0.15775389962245462 1027872.9065733532
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 435 10190.0 1.8850152585695068 0.27341739354641087 0.9999999999995436 -0.0014095017842237212
# 440 10200.0 1.9325258518296093 0.2800338900709417 0.156975814128886 1045602.2278570546
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 440 10170.0 1.8817386882453275 0.2734788934540219 0.9999999999999429 -0.00124804386661026
# 445 10190.0 1.9325488860648345 0.280312043590486 0.15603942448485386 1068254.7259628458
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 445 10160.0 1.8810219802445383 0.27364380168559904 1.0000000000028406 -0.0013261911317812292
# 450 10180.0 1.9325331096061618 0.280585108643371 0.15512038947151524 1091142.8365894111
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 450 10150.0 1.8802626730093446 0.27380283158207375 1.0000000000000895 0.0001272406510821611
# 455 10170.0 1.9325087625765027 0.28085746510980014 0.15414214996393186 1111070.0891796087
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 455 10140.0 1.8796230484186511 0.2739796204563197 1.0000000000071418 -0.00015498405707603524
# 460 10160.0 1.9324146479400832 0.28112020818944294 0.1532579042878582 1134398.0247866747
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 460 10130.0 1.8787788085994812 0.2741269035849314 1.000000000001768 0.0012152097944806428
# 465 10150.0 1.9323054839827858 0.2813812775154883 0.1523165466515762 1154703.571556378
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 465 10120.0 1.8780494102673682 0.2742912505166062 0.9999999999985685 0.0015623599249181552
# 470 10140.0 1.932138082417269 0.28163437287877846 0.1514651837986648 1178471.2295718244
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 470 10110.0 1.8771255051453561 0.2744274865293055 0.9999999999990524 0.002612365252346649
# 475 10130.0 1.93195511388859 0.28188569660850016 0.15052364908829716 1197495.7148269268
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 475 10100.0 1.8763850065089474 0.2745908320849473 1.0000000000026092 0.0028426765719160585
# 480 10120.0 1.9317207787339121 0.2821300148713364 0.1496696866318772 1220012.714985226
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 480 10090.0 1.87545623096706 0.2747269216033672 1.0000000000001443 0.003430279119129409
# 485 10110.0 1.931448477133423 0.2823692659269131 0.14889873716646218 1246114.4021809201
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 485 10080.0 1.8743504168146543 0.27483732184451276 1.0000000000108245 0.0038396675573011407
# 490 10100.0 1.931149713026722 0.282605118214627 0.14804114553619185 1267365.2904455059
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 490 10070.0 1.873419842686791 0.2749736624364625 1.0000000000000098 0.004505192221586185
# 495 10090.0 1.9308188786223166 0.2828367401696464 0.14726450190795587 1292231.8351798577
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 495 10060.0 1.8723174914660232 0.27508503621199915 1.0000000000037548 0.005186603057381944
# 500 10080.0 1.9304563016396463 0.28306416725542743 0.14646919901754887 1315597.0830056511
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 500 10050.0 1.871249497298797 0.27520168446405674 0.9999999999945896 0.005663618060538056
