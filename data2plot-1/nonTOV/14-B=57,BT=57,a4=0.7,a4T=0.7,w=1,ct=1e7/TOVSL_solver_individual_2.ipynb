# %%
# deleting profile and radmass files
import os

if os.path.exists('profileSL.dat'):
    os.remove('profileSL.dat')

if os.path.exists('radmassSL.dat'):
    os.remove('radmassSL.dat')

# %%
# source: https://www.codesansar.com/numerical-methods/
#         runge-kutta-fourth-order-rk4-python-program.htm

import cmath #To help us out with the complex square root
import numpy as np #For the arrays
import matplotlib.pyplot as plt #Visualization

# deleting profile and radmass files
# os.remove("radmass.txt")
# os.remove("profile.txt")

# some constants
GS = 1.325 * 10**(-12) # Newton constant in fm^3 / MeV m^2
MSS = 1.1155 * 10**(15) # Sun's mass in MeV m^3 / fm^3
PI = np.pi 
HC = 197.327 # hc=1=197.327 MeV fm
KN = 8*PI*GS

# constants in eden
B = 57 # MeV
w = 1. # speed of sound
a4 = 0.7 # don't know, dimensionless
ms = 100 # quark mass in MeV

# additional constants for tangential pressure
BT = 57 # MeV
a4t = 0.7 # don't know, dimensionless

# constants for SL model
ctilde = 1.e7 # meter^2

# masalah satuan 
alpha = ms**2/(3*PI*np.sqrt(a4))*HC**(-1.5)
beta = ms**4/(12*PI**2)*(1-1/a4)*HC**(-3)
gamma = 8*PI/(3*ms**2*np.sqrt(a4))*HC**(1.5)
kappa = 3/(1-1/a4)

alphat = ms**2/(3*PI*np.sqrt(a4t))*HC**(-1.5)
betat = ms**4/(12*PI**2)*(1-1/a4t)*HC**(-3)
gammat = 8*PI/(3*ms**2*np.sqrt(a4t))*HC**(1.5)
kappat = 3/(1-1/a4t)

# %%
# define energy density as function of pressure

def eden(P):
    sqdoe = alpha**2 + 4*w*P + 12*w**2*B
    doeden = alpha**2/(2*w**2) + alpha/(2*w**2)*np.sqrt(sqdoe)
    lgPt = gamma*np.sqrt(P/w + 3*B + doeden)
    Ptilde = P - beta*(1+kappa*np.log(lgPt))
    sqde = alpha**2 + 4*w*Ptilde + 12*w**2*B
    deden = alpha**2/(2*w**2) + alpha/(2*w**2)*np.sqrt(sqde)
    # print("cek eden: ",sqdoe,doeden,lgPt,Ptilde,sqde,deden)
    return P/w + 4*B + deden

def dedP(P):
    dP = 0.00001
    x1 = P-2*dP
    x2 = P-dP
    x3 = P+dP
    x4 = P+2*dP
    dedP = eden(x1) - 8*eden(x2) + 8*eden(x3) - eden(x4)
    dedP = dedP/(12*dP)
    return dedP

# define tangential pressure

def fpt(ed,PCC):
    fpt = PCC + w*(ed-4*BT) - alphat*np.sqrt(ed-BT)
    fpt = fpt + betat*(1+kappat*np.log(gammat*np.sqrt(ed-BT)))
    fpt = fpt - w*(eden(PCC)-4*BT) + alphat*np.sqrt(eden(PCC)-BT)
    fpt = fpt - betat*(1+kappat*np.log(gammat*np.sqrt(eden(PCC)-BT)))
    return fpt

def dPTde(ed):
    return w-(1/2)*alphat/np.sqrt(ed-BT)+(1/2)*betat*kappat/(ed-BT)

# define sigma

def sig(P,PCC):
    ed = eden(P)
    Ptan = fpt(ed,PCC)
    sig = P - Ptan
    return sig

def dsdP(P,PCC):
    dP = 0.00001
    x1 = P-2*dP
    x2 = P-dP
    x3 = P+dP
    x4 = P+2*dP
    dsdP = sig(x1,PCC) - 8*sig(x2,PCC) + 8*sig(x3,PCC) - sig(x4,PCC)
    dsdP = dsdP/(12*dP)
    return dsdP


# the TOV SL equation

def b1(r,P,m,b,Lambda):
    Pcorr0 = Lambda - (1/2)*(eden(P)+P)**2 - 2*sig(P,PCC)*(eden(P)+P) 
    Pcorr = P - (KN/4)*ctilde*Pcorr0
    return (4*PI*r**3*Pcorr+MSS*m)*2*GS/(2*r*(r-2*GS*MSS*m))*2*b

def P1(r,P,m,b,Lambda):
    return -(eden(P)+P) * b1(r,P,m,b,Lambda)/(2*b) -2*sig(P,PCC)/r

def m1(r,P,m,b,Lambda):
    edencorr0 = Lambda - (3/2)*(eden(P)+P)**2 + 2*sig(P,PCC)*(eden(P)+P) 
    edencorr = eden(P) + (KN/4)*ctilde*edencorr0
    return 4*PI*r**2*edencorr/MSS

def L1(r,P,m,b,Lambda):
    ed = eden(P)
    dsde=1/dedP(P)-dPTde(ed)
    sigprime = dsdP(P,PCC)*P1(r,P,m,b,Lambda)
    sigprime = sigprime + dsde*dedP(P)*P1(r,P,m,b,Lambda)
    Lambda1 = P1(r,P,m,b,Lambda)*(eden(P)+P-2*sig(P,PCC))*(1-dedP(P))
    Lambda1 = Lambda1 + 8*sig(P,PCC)/r*(eden(P)+P-sig(P,PCC))
    Lambda1 = Lambda1 + 2*sigprime*(eden(P)+P)
    return Lambda1

# %%
# define the Runge-Kutta 4th order for the problem
# if we want to print the profile, set profile=1
# if we not, set profile=0
def RungeKutta(rCC,bCC,LCC,PCC,MCC,h,profile):
    # input initial values
    r0 = rCC
    b0 = bCC
    P0 = PCC
    m0 = MCC
    L0 = LCC
    while (P0 > 0.):
        if profile == 1:
            f0 = 1-2*GS*MSS*m0/r0
            print(r0/1000, b0, P0, m0, abs(L0/1.e+6), f0, file=open('profileSL.dat', 'a'))
        # calculate k1
        r01 = r0
        b01 = b0
        P01 = P0
        m01 = m0
        L01 = L0
        k1_b = h * b1(r01,P01,m01,b01,L01)
        k1_P = h * P1(r01,P01,m01,b01,L01)
        k1_m = h * m1(r01,P01,m01,b01,L01)
        k1_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k2
        r01 = r0 + h/2
        b01 = b0 + k1_b/2
        P01 = P0 + k1_P/2
        m01 = m0 + k1_m/2
        L01 = L0 + k1_L/2
        k2_b = h * b1(r01,P01,m01,b01,L01)
        k2_P = h * P1(r01,P01,m01,b01,L01)
        k2_m = h * m1(r01,P01,m01,b01,L01)
        k2_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k3
        r01 = r0 + h/2
        b01 = b0 + k2_b/2
        P01 = P0 + k2_P/2
        m01 = m0 + k2_m/2
        L01 = L0 + k2_L/2
        k3_b = h * b1(r01,P01,m01,b01,L01)
        k3_P = h * P1(r01,P01,m01,b01,L01)
        k3_m = h * m1(r01,P01,m01,b01,L01)
        k3_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k4
        r01 = r0 + h
        b01 = b0 + k3_b
        P01 = P0 + k3_P
        m01 = m0 + k3_m
        L01 = L0 + k3_L
        k4_b = h * b1(r01,P01,m01,b01,L01)
        k4_P = h * P1(r01,P01,m01,b01,L01)
        k4_m = h * m1(r01,P01,m01,b01,L01)
        k4_L = h * L1(r01,P01,m01,b01,L01)
        # calculate the next r0, P0, m0, and b0
        r0 = r0 + h
        b0 = b0 + (k1_b+2*k2_b+2*k3_b+k4_b)/6
        P0 = P0 + (k1_P+2*k2_P+2*k3_P+k4_P)/6
        m0 = m0 + (k1_m+2*k2_m+2*k3_m+k4_m)/6
        L0 = L0 + (k1_L+2*k2_L+2*k3_L+k4_L)/6
        f0 = 1-2*GS*MSS*m0/r0
        # print(P0)
    if profile == 1:
        f0 = 1-2*GS*MSS*m0/r0
        print(r0/1000, b0, P0, m0, abs(L0/1.e+6), f0, file=open('profileSL.dat', 'a'))
    # the results at the surface
    output = np.array([r0,b0,P0,m0,L0,f0])
    return output
# define for a single PCC

def single_PCC(x,radmassdata,profile):
    # define initial parameters
    rCC = 1.*10**(-12) # radius near center in m--the starting point
    rmax = 100000. # radius at far distances in m
    PCC = x # pressure at the center in MeV / fm^3
    MCC = (4*PI/3)*eden(PCC)*rCC**3/MSS # Mass at the center in MeV m^3 / fm^3
    bCC = 1-2*GS*MSS*MCC/rCC # metric function b(r) at the center
    LCC = 1.*10**(-12) # Lambda function at center

    h = 10./2 # h-step

    # calculate the surface values
    output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
    # print(output)

    # at the surface, b = 1-2Gm/r, which is different to the result
    rSurface=output[0]
    bSurface=output[1]
    mSurface=output[3]
    bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface

    # So, we redefine bCC as follows
    bCorrection=bSurfaceTarget/bSurface
    # print("cek bCC ",abs(bCorrection-1))

    # if abs(LSurface) not near 0, then recalculate
    LSurface=output[4]
    print(PCC, rSurface, mSurface, GS*MSS*mSurface/rSurface, bCorrection, LSurface)

    # if abs(bCorrection) not near 1, then recalculate
    while (abs(bCorrection-1)>10**(-3)):
        while (abs(LSurface)>10**(-1)):
            print("abs(LSurface)>10**(-1)")
            if ctilde==0:
                break
            LCC = LCC - LSurface
            output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
            LSurface=output[4]
            # print("cek LCC ",(LSurface))
            # print(output)
        print("abs(bCorrection-1)>10**(-3)")
        bCC=bCC*bCorrection
        output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
        rSurface=output[0]
        bSurface=output[1]
        mSurface=output[3]
        bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface
        bCorrection=bSurfaceTarget/bSurface

    rSurface=output[0]
    bSurface=output[1]
    mSurface=output[3]
    bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface
    bCorrection=bSurfaceTarget/bSurface
    LSurface=output[4]
    print(PCC, rSurface, mSurface, GS*MSS*mSurface/rSurface, bCorrection, LSurface)

    if profile == 1:
        output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,profile)
        # print(output)
    if radmassdata == 1:
        print(PCC, (eden(PCC)/1000), (rSurface/1000), mSurface, 
            2*GS*MSS*mSurface/rSurface, abs(LCC/1.e+6), 0.5*np.log(bCC),
            file=open('radmassSL.dat', 'a'))

    output2=np.array([PCC, (eden(PCC)/1000), (rSurface/1000), mSurface, GS*MSS*mSurface/rSurface])
    return output2

# %%
# PCC=500
# single_PCC(PCC,0,1)

# %%
# this is for multiple PCC
for x in range(5, 501, 5):
    PCC=x
    if PCC==500:
        single_PCC(PCC,1,1)
    else:
        single_PCC(PCC,1,0)
# Out:
# 5 5440.000000000001 0.1384414193175914 0.03761426641629125 0.8869036501940756 30.145404787695806
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 5 5440.000000000001 0.13843987077535805 0.03761384568035536 1.0000001017742355 0.0005652378413554329
# 10 7330.000000000001 0.3412518955710522 0.06881079107777612 0.7945461769123386 64.0794729545043
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 10 7330.000000000001 0.34124371138976345 0.06880914080126158 1.0000007748264819 0.0021400361629679704
# 15 8585.0 0.5523190397094151 0.09509007019854449 0.7178775309480792 92.5870153042476
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 15 8585.0 0.5522997927281172 0.09508675653982346 1.0000022703243854 0.004159213054395483
# 20 9505.0 0.7549972518572854 0.11740286697969617 0.6536684589811844 131.40105434495285
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 20 9505.0 0.7549597890970899 0.11739704148107204 1.0000051804543577 0.007086446241818603
# 25 10220.0 0.9451007400483837 0.1366824202611803 0.59891043815846 157.69335062421177
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 25 10220.0 0.9450443721334233 0.1366742682169427 1.0000088396339486 0.00962492591821218
# 30 10795.0 1.1213208009898927 0.1535298002216858 0.5516794053661814 184.2541919004462
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 30 10795.0 1.1212426359742171 0.15351909796838736 1.0000136078848585 0.012273822034930326
# 35 11260.0 1.281012172860665 0.16815133476416916 0.5111349411143338 225.48268304054656
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 35 11260.0 1.280902992265573 0.16813700323541086 1.0000207630848688 0.015987016284271155
# 40 11650.0 1.4279420413057504 0.18116325192072513 0.4754686208730993 245.19139202723144
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 40 11650.0 1.427809922648495 0.18114649000399782 1.0000271500124305 0.01819166216320678
# 45 11980.0 1.562386381385075 0.19276007188451105 0.44406986706091833 311.50526702843456
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 45 11980.0 1.5622031423825307 0.19273746469609507 1.0000403290936024 0.023880686093267267
# 50 12260.0 1.6847946465454944 0.20311498102720113 0.41626166252501773 315.8401724517154
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 50 12260.0 1.684594883472289 0.20309089804895372 1.000046754926175 0.024779932928968518
# 55 12500.0 1.796285719654504 0.21239821234910744 0.39159206591837253 368.58681563524476
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 55 12500.0 1.7960379875177712 0.2123689197580638 1.0000612841968743 0.029371878167645554
# 60 12710.0 1.8992581869938874 0.2208634793516111 0.3693169345185447 388.83700749613473
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 60 12710.0 1.8989828605133463 0.2208314618171514 1.000071665429928 0.0312926036531829
# 65 12890.0 1.992252168691134 0.228442468175471 0.3495369674288401 478.71540262329347
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 65 12890.0 1.99189799361058 0.22840185653461575 1.0000965352252413 0.038717382711862175
# 70 13050.0 2.078828452824144 0.23544723443226553 0.3313821710414459 446.0086523271898
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 70 13050.0 2.0784855663782578 0.23540839925791598 1.0000975758416402 0.03611164154564453
# 75 13190.0 2.1579818673792905 0.24181790176699147 0.31502147635095495 483.96248218099436
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 75 13190.0 2.15759729363143 0.2417748074212103 1.0001138662957934 0.03910997640551417
# 80 13315.0 2.2313906887562474 0.24769651634491635 0.30009779362379846 598.4035175580221
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 80 13315.0 2.230901135671608 0.24764217328691127 1.0001504008984496 0.04812581449880199
# 85 13425.0 2.298901172756922 0.25309960090344197 0.28641341472769777 600.4483736251866
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 85 13425.0 2.2983973836029152 0.2530441357815265 1.0001602176258986 0.0479510671636858
# 90 13525.0 2.362234366682257 0.25814942534159896 0.2737900085018838 680.9242195981979
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 90 13520.0 2.3593100721907256 0.25792520420307685 1.0000000000000164 -2.0324798607695982e-05
# 95 13610.0 2.4189379114329372 0.26269514645624975 0.26239328325337513 722.7570553238318
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 95 13610.0 2.4183057144221403 0.26262649025571 1.0002140294750081 0.05661801606912176
# 100 13690.0 2.473516505526765 0.26705260423940946 0.25161402025885105 723.5833147916038
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 100 13690.0 2.4728723138483892 0.26698305424248997 1.0002244878629805 0.05601954318619312
# 105 13760.0 2.523328731682448 0.27104465772195463 0.2417870293277955 808.3057877583102
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 105 13760.0 2.522598062780613 0.27096617254484734 1.0002615661444982 0.06176648498933829
# 110 13825.0 2.5708560282662836 0.27485147319194403 0.2324801191980853 764.5643676525277
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 110 13825.0 2.5701551790034887 0.2747765450550719 1.000257484964875 0.05759928119588975
# 115 13880.0 2.6133397565374543 0.27828632279562154 0.2240828399902983 851.1091163873886
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 115 13880.0 2.6125504410788487 0.27820227107752726 1.0002969949068985 0.06316741121997554
# 120 13930.0 2.653285184860921 0.2815258436050878 0.21620207953218143 894.4981849388769
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 120 13930.0 2.6524469314650525 0.28143690103842617 1.0003226848683313 0.06536675047962426
# 125 13980.0 2.693077947513692 0.28472605127670014 0.2086007618367653 985.2262610370312
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 125 13975.0 2.689645097244027 0.2844648526238152 0.9999999999998808 -2.3020341839707914e-05
# 130 14020.0 2.727761684859632 0.2875701898206646 0.20172016589158198 982.9806063806303
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 130 14020.0 2.7268234005172314 0.2874712725992858 1.0003770698745535 0.06944968187594824
# 135 14060.0 2.762272736650145 0.2903799921761407 0.19505011153868423 931.1329533207336
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 135 14060.0 2.7613768081466765 0.2902858089666495 1.0003674387894121 0.06462450127759933
# 140 14095.0 2.7939709315303283 0.2929828883087447 0.18891651136503074 1073.379340036598
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 140 14090.0 2.7903897986577957 0.29271119673766294 1.0000000000003166 -3.626816041857328e-05
# 145 14125.0 2.8229476565536205 0.2953927431450174 0.18319196996653217 1119.0699683937762
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 145 14125.0 2.821857236661989 0.2952786418005518 1.0004640972985968 0.07488585253291935
# 150 14150.0 2.849132869948436 0.2976060229163541 0.1778931642939746 1165.0382273668486
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 150 14150.0 2.847992391478433 0.29748689429821934 1.0004936951876329 0.07653792381536234
# 155 14180.0 2.8776703849475567 0.29995096908264623 0.1725051076971355 1107.5290159740366
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 155 14175.0 2.8740081342748742 0.29967490636778116 0.9999999999990015 -2.091283587984938e-05
# 160 14200.0 2.90076695814806 0.30193255935941987 0.16783768798207632 1365.266144654472
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 160 14200.0 2.8994181979311637 0.30179217075525927 1.0006034047203314 0.08629670170777037
# 165 14220.0 2.9236687822922858 0.3038883331791374 0.16323916564906257 1306.2799186191316
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 165 14220.0 2.922373829636302 0.30375373482567264 1.0005882885311486 0.08095496150775128
# 170 14240.0 2.946307344644855 0.305811288055514 0.15884126620780786 1464.5028420264664
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 170 14240.0 2.9448505385811337 0.3056600792077325 1.0006717911387086 0.08894374745075945
# 175 14260.0 2.9687242034030397 0.3077058695503029 0.154511764551624 1290.7203482600964
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 175 14255.0 2.964834909369726 0.30741053506541954 0.9999999999999981 -4.152007339985886e-05
# 180 14275.0 2.988293250603424 0.3094087205176012 0.1506072279692037 1451.5527145008311
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 180 14270.0 2.9842345172425824 0.309096743187031 1.0000000000003855 6.225284600036574e-06
# 185 14285.0 3.005021897509624 0.310922999848819 0.14703752597505299 1616.3045811373831
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 185 14285.0 3.0034027555163028 0.3107554707914894 1.0007779764786007 0.09234583715362332
# 190 14300.0 3.0241015875430874 0.31256891959428074 0.14330915949156142 1432.2656854597597
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 190 14300.0 3.022663525703822 0.3124202825784938 1.0007002099043534 0.0800762622457113
# 195 14310.0 3.0403672780427313 0.314030527653395 0.13996449601835648 1599.9443178849922
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 195 14310.0 3.0387588329598767 0.31386439612655015 1.0007927328955408 0.08765012466967209
# 200 14320.0 3.0563733362320145 0.3154632964351275 0.1366860342947162 1528.6026048454971
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 200 14320.0 3.0548347182831814 0.31530448812321765 1.0007674517776606 0.08195731829551073
# 205 14330.0 3.0721757525804256 0.31687306133318843 0.13352792181175496 1577.5022771794384
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 205 14330.0 3.07058596287107 0.31670908584068724 1.0008023272894004 0.08279608180469705
# 210 14335.0 3.0851315272702418 0.3180983669157788 0.1306635798927732 1626.4227325076743
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 210 14335.0 3.08349211979808 0.3179293326833661 1.0008362681402991 0.08361071521158314
# 215 14345.0 3.1005741666727435 0.31946775112398496 0.12772455497670807 1931.0276931277235
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 215 14345.0 3.0986253323544313 0.31926695292225943 1.0000000000045057 0.09710870549103756
# 220 14350.0 3.113154611784935 0.32065221320669507 0.12504829491285233 2113.963416562971
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 220 14350.0 3.111020647655354 0.32043241676020207 1.0000000000024891 -1.1646792681008211e-05
# 225 14355.0 3.125416438944631 0.3218030442268634 0.12240899778379075 1907.5682776831625
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 225 14355.0 3.1234906127979554 0.3216047549016619 1.0000000000013918 0.09191489517502016
# 230 14360.0 3.137555489439591 0.32294043674948253 0.1198775887278631 1960.1878348534592
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 230 14360.0 3.135576201320712 0.32273671376459334 1.0000000000000029 0.09241535522885819
# 235 14365.0 3.1495025121588447 0.32405727945109486 0.11742119597518441 2013.237019920436
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 235 14365.0 3.1474693170527215 0.32384808080078736 1.0000000000103313 0.09279654423173567
# 240 14365.0 3.1586189966163065 0.3249952889113313 0.11521762784326992 2066.2243093715765
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 240 14365.0 3.156534063330943 0.32478076683818363 1.0000000000030191 0.09330510187971153
# 245 14370.0 3.1701956882180093 0.3260729373364318 0.11290041696709502 2120.109360989947
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 245 14370.0 3.1680560317320428 0.32585286130836105 0.9999999999832683 0.09358781772964342
# 250 14370.0 3.178890177873727 0.3269672158162169 0.11081514943616105 2033.1850651562181
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 250 14370.0 3.176840010126801 0.3267563442218365 0.9999999999797017 0.08787435155994522
# 255 14375.0 3.190238922679894 0.3280203660299466 0.10864802927335314 2371.240770269077
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 255 14375.0 3.187847347970969 0.327774464318375 0.9999999999922715 4.058765797299024e-05
# 260 14375.0 3.198453493212905 0.3288649881721508 0.10666367454801666 1994.1273968490484
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 260 14375.0 3.196444109796208 0.3286583833692461 1.0000000000047162 0.08231530825610645
# 265 14375.0 3.206832892520399 0.32972655800894735 0.1047835366845608 2338.1840842733855
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 265 14375.0 3.2044787787362754 0.3294845080296637 0.9999999999999819 0.0944734804929861
# 270 14375.0 3.21506518785556 0.33057300261530864 0.10295465914513244 2690.244248773476
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 270 14375.0 3.212358755204299 0.330294727210106 1.000000000005616 3.436630272235508e-05
# 275 14375.0 3.223001380290329 0.33138900192145154 0.1011590113905427 2749.7941270879537
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 275 14375.0 3.2202373765301346 0.33110480705482837 0.9999999999991452 2.9029032944105637e-05
# 280 14375.0 3.2304664205813096 0.3321565573641702 0.09938252068430416 2201.0746093164794
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 280 14375.0 3.2282559916041556 0.3319292810567392 0.9999999999946692 0.08316318109506804
# 285 14375.0 3.2382556485134333 0.33295744578015113 0.09770043706311399 2561.873996153569
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 285 14375.0 3.2356850023701638 0.33269313194370015 0.9999999999949519 0.09460051819436943
# 290 14375.0 3.246085516955476 0.33376251285336195 0.09607603138840688 3242.5991617061823
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 290 14375.0 3.2428343113559723 0.333428223893621 0.9999999999987166 -6.749268603023495e-05
# 295 14375.0 3.2532647404581323 0.3345006806139051 0.09445499226703849 2991.6691334244774
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 295 14375.0 3.2502676798439083 0.33419252284155054 1.0000000000001503 2.724442843837771e-05
# 300 14370.0 3.2578329285726912 0.33508693369278064 0.09304511435419698 3052.4998350595947
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 300 14370.0 3.254780530532737 0.3347729769239582 0.9999999999994836 -5.483778344161916e-05
# 305 14370.0 3.264724061871319 0.33579572655519335 0.09150899535192372 2790.8400548496556
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 305 14370.0 3.261935757739989 0.3355089333702587 1.0000000000054976 0.09406534679726264
# 310 14370.0 3.271669588329505 0.3365101140682373 0.09002462584912958 2849.090921400306
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 310 14370.0 3.268825423783521 0.3362175753170101 1.0000000000042435 0.09373400396606979
# 315 14365.0 3.2760462492847378 0.33707756409169437 0.088737703867078 3238.132969310588
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 315 14365.0 3.2728194363754715 0.3367455522235858 0.9999999999804832 1.228729957780672e-07
# 320 14365.0 3.2825403244890916 0.33774574972899724 0.08731802244149243 2966.0702509612056
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 320 14365.0 3.279587166128403 0.3374418946088763 1.0000000000000269 0.09323182176788769
# 325 14360.0 3.2864735168097656 0.3382681824931555 0.08608984231771277 3024.7845311811857
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 325 14360.0 3.283467343371173 0.3379587648696358 0.9999999999977803 0.09293236850608333
# 330 14360.0 3.293370243403153 0.3389780446472136 0.0847636583019819 3769.230523246276
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 330 14360.0 3.2896269886073397 0.33859276115415876 1.0000000000000044 -7.91790624932176e-06
# 335 14355.0 3.296636178208761 0.3394323855972992 0.08358427659759923 3143.7507816872194
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 335 14355.0 3.2935198917967097 0.33911152261034333 0.9999999999667963 0.0920684074369964
# 340 14355.0 3.3026397056256407 0.3400505283109479 0.0823018335939326 2853.959366680169
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 340 14355.0 3.2998129674847436 0.33975947815595475 0.9999999999879157 0.08153843321591492
# 345 14350.0 3.3065905371766116 0.3405759450238449 0.08120838561679063 3617.865053433576
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 345 14350.0 3.30301337579853 0.3402075005178968 0.9999999999859219 -3.032633771371529e-05
# 350 14345.0 3.3094968239425007 0.3409941033055359 0.08012008448295944 2966.672865864743
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 350 14345.0 3.3065689207951277 0.3406924267180012 0.999999999994368 0.08104569883919344
# 355 14345.0 3.316144338543507 0.3416790301693969 0.0789462917189296 4108.487796802864
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 355 14345.0 3.312092416490217 0.3412615402605896 0.9999999999764817 1.6280323081430126e-05
# 360 14340.0 3.318581815908451 0.3420493982378512 0.07790944683961788 3081.2117534440413
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 360 14340.0 3.3155486176684494 0.3417367635974288 1.0000000000030018 0.08013807261949757
# 365 14335.0 3.321404034349196 0.34245969413459354 0.0769073855788289 2769.565948778404
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 365 14335.0 3.3186824748885395 0.3421790825586375 0.9999999999984146 0.07035836801650097
# 370 14335.0 3.3277973869834367 0.34311889294478765 0.0758097673248605 3942.7875665401675
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 370 14335.0 3.323925735873316 0.3427196989770391 1.000000000000513 0.09752152950844684
# 375 14330.0 3.330431654216584 0.34351031933839105 0.07485639082567891 3631.7512344416577
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 375 14330.0 3.3268717312344442 0.34314313862208157 0.9999999999385563 0.08776112441870776
# 380 14325.0 3.3335077954731687 0.34394761104723715 0.07393045984225301 4074.4290175506244
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 380 14325.0 3.329520876219002 0.3435362451716958 0.9999999999951356 0.09612815753025128
# 385 14320.0 3.335679749719302 0.3442918825471887 0.07302080212361177 3372.0448949249817
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 385 14320.0 3.332385967493738 0.34395191511379364 1.0000000000287346 0.07761922085802664
# 390 14320.0 3.341775739702247 0.34492107959987145 0.07201258506490639 4595.985225794412
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 390 14320.0 3.3372894734679672 0.344458030037773 0.9999999999639985 0.00012246116597736112
# 395 14315.0 3.343477231378252 0.3452172356530376 0.07114644039715136 3490.8231033897414
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 395 14315.0 3.340075854896714 0.3448660402641915 1.0000000000008074 0.07618760660613644
# 400 14310.0 3.3465183636134173 0.3456519661676635 0.07030399641912916 4341.852960980912
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 400 14310.0 3.342294952053107 0.34521574250141107 0.9999999999089622 0.09252958660343757
# 405 14305.0 3.3483209400548377 0.34595902911124093 0.06947961160910562 3610.1675646317067
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 405 14305.0 3.344815385108546 0.345596824171085 0.999999999999968 0.0751975336985038
# 410 14305.0 3.3535460356502145 0.34649890238849024 0.06855190701810993 4074.243914764225
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 410 14300.0 3.346975430671325 0.3459409229448159 1.0000000000000204 -1.0996041473809726e-05
# 415 14300.0 3.355777709151935 0.34685071998536027 0.06776558247465453 4138.440291191241
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 415 14300.0 3.3517688935922454 0.34643637175264663 1.000000000029619 0.08152629905427267
# 420 14295.0 3.3582435234880155 0.34722699278400954 0.06699556218057338 4613.901020503366
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 420 14295.0 3.3537816958199453 0.34676566024732225 0.999999999954066 0.0887131251499309
# 425 14290.0 3.3593953203573417 0.347467617971495 0.0662480935603076 3438.091591909761
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 425 14290.0 3.35607631480172 0.34712432793133285 1.000000000053218 0.06444991933253852
# 430 14285.0 3.3617181644470655 0.3478295772827391 0.06551156252499775 3914.1104753434456
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 430 14285.0 3.357945974130284 0.347439277055554 0.9999999999775496 0.07141159975417233
# 435 14280.0 3.3639806328098167 0.34818554093603915 0.06479038478117166 4398.020115409358
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 435 14280.0 3.3597491755355122 0.3477475680697177 0.9999999999961825 0.07819819774466408
# 440 14280.0 3.3684715158775305 0.348650365416585 0.06397133084517746 4464.227693046945
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 440 14280.0 3.3641793129708324 0.3482061051327119 1.000000000029418 0.07709814207787746
# 445 14275.0 3.3706121271549967 0.34899412412538366 0.06328087770762347 4960.108664083973
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 445 14275.0 3.365851086457762 0.3485011646375001 1.000000000048134 0.08322994449728616
# 450 14270.0 3.372027730508777 0.3492630299041251 0.0626107804127682 4596.216039559754
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 450 14270.0 3.367623397912512 0.34880684428816494 0.9999999999979221 0.07496688851509725
# 455 14265.0 3.373710501111157 0.3495598061539489 0.0619520670963752 4662.613853925815
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 455 14265.0 3.369249981108116 0.34909763890305545 0.9999999999897762 0.07428031670091562
# 460 14260.0 3.3753315913387456 0.34985039740065493 0.061307187186932476 4729.278670001822
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 460 14260.0 3.370814803583794 0.349382235992425 0.9999999999947529 0.0730602600137974
# 465 14255.0 3.376892360404592 0.3501349380667486 0.06067575253919242 4796.208709630319
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 465 14255.0 3.3723192269540108 0.349660770214594 1.000000000015626 0.07208662888484407
# 470 14250.0 3.3780431627452323 0.35037715587060037 0.06006162971086807 4414.343284440949
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 470 14250.0 3.3738411200238416 0.34994131189033245 0.9999999999987278 0.06448238311377297
# 475 14250.0 3.3831515062596673 0.35090700311812434 0.05933437896026415 5837.229750485086
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 475 14250.0 3.3775984434287203 0.3503310287248615 1.000000000000828 0.08270702545602937
# 480 14245.0 3.383467162892477 0.35106292360643654 0.058755793831038454 4542.544079058496
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 480 14245.0 3.3791529775845213 0.3506152909165729 1.0000000000494447 0.062457081600613584
# 485 14240.0 3.385520790579784 0.35139934589231503 0.05816565077339719 5527.674699292597
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 485 14240.0 3.380279461493794 0.35085532335446856 0.9999999999867694 0.07388443030174541
# 490 14235.0 3.3868014175902514 0.351655742904921 0.05759672267790713 5599.716622815551
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 490 14235.0 3.3815004242356816 0.3511053342666839 1.0000000000288944 0.0727498205775996
# 495 14230.0 3.387286509969217 0.3518296897384839 0.05705009856647443 4735.827404718968
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 495 14230.0 3.3828106893020338 0.3513647964995962 0.9999999999996109 0.05951213168728664
# 500 14225.0 3.3892049840168514 0.35215269325580356 0.05649268102931765 5744.566905669258
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 500 14225.0 3.3837844806227424 0.35158948008987245 0.9999999999861423 0.07031035135601871
