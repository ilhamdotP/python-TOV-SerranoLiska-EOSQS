# %%
# deleting profile and radmass files
import os

if os.path.exists('profileSL.dat'):
    os.remove('profileSL.dat')

if os.path.exists('radmassSL.dat'):
    os.remove('radmassSL.dat')

# %%
# source: https://www.codesansar.com/numerical-methods/
#         runge-kutta-fourth-order-rk4-python-program.htm

import cmath #To help us out with the complex square root
import numpy as np #For the arrays
import matplotlib.pyplot as plt #Visualization

# deleting profile and radmass files
# os.remove("radmass.txt")
# os.remove("profile.txt")

# some constants
GS = 1.325 * 10**(-12) # Newton constant in fm^3 / MeV m^2
MSS = 1.1155 * 10**(15) # Sun's mass in MeV m^3 / fm^3
PI = np.pi 
HC = 197.327 # hc=1=197.327 MeV fm
KN = 8*PI*GS

# constants in eden
B = 57 # MeV
w = 1/3. # speed of sound
a4 = 0.7 # don't know, dimensionless
ms = 100 # quark mass in MeV

# additional constants for tangential pressure
BT = 57 # MeV
a4t = 0.7 # don't know, dimensionless

# constants for SL model
ctilde = 1.e7 # meter^2

# masalah satuan 
alpha = ms**2/(3*PI*np.sqrt(a4))*HC**(-1.5)
beta = ms**4/(12*PI**2)*(1-1/a4)*HC**(-3)
gamma = 8*PI/(3*ms**2*np.sqrt(a4))*HC**(1.5)
kappa = 3/(1-1/a4)

alphat = ms**2/(3*PI*np.sqrt(a4t))*HC**(-1.5)
betat = ms**4/(12*PI**2)*(1-1/a4t)*HC**(-3)
gammat = 8*PI/(3*ms**2*np.sqrt(a4t))*HC**(1.5)
kappat = 3/(1-1/a4t)

# %%
# define energy density as function of pressure

def eden(P):
    sqdoe = alpha**2 + 4*w*P + 12*w**2*B
    doeden = alpha**2/(2*w**2) + alpha/(2*w**2)*np.sqrt(sqdoe)
    lgPt = gamma*np.sqrt(P/w + 3*B + doeden)
    Ptilde = P - beta*(1+kappa*np.log(lgPt))
    sqde = alpha**2 + 4*w*Ptilde + 12*w**2*B
    deden = alpha**2/(2*w**2) + alpha/(2*w**2)*np.sqrt(sqde)
    # print("cek eden: ",sqdoe,doeden,lgPt,Ptilde,sqde,deden)
    return P/w + 4*B + deden

def dedP(P):
    dP = 0.00001
    x1 = P-2*dP
    x2 = P-dP
    x3 = P+dP
    x4 = P+2*dP
    dedP = eden(x1) - 8*eden(x2) + 8*eden(x3) - eden(x4)
    dedP = dedP/(12*dP)
    return dedP

# define tangential pressure

def fpt(ed,PCC):
    fpt = PCC + w*(ed-4*BT) - alphat*np.sqrt(ed-BT)
    fpt = fpt + betat*(1+kappat*np.log(gammat*np.sqrt(ed-BT)))
    fpt = fpt - w*(eden(PCC)-4*BT) + alphat*np.sqrt(eden(PCC)-BT)
    fpt = fpt - betat*(1+kappat*np.log(gammat*np.sqrt(eden(PCC)-BT)))
    return fpt

def dPTde(ed):
    return w-(1/2)*alphat/np.sqrt(ed-BT)+(1/2)*betat*kappat/(ed-BT)

# define sigma

def sig(P,PCC):
    ed = eden(P)
    Ptan = fpt(ed,PCC)
    sig = P - Ptan
    return sig

def dsdP(P,PCC):
    dP = 0.00001
    x1 = P-2*dP
    x2 = P-dP
    x3 = P+dP
    x4 = P+2*dP
    dsdP = sig(x1,PCC) - 8*sig(x2,PCC) + 8*sig(x3,PCC) - sig(x4,PCC)
    dsdP = dsdP/(12*dP)
    return dsdP


# the TOV SL equation

def b1(r,P,m,b,Lambda):
    Pcorr0 = Lambda - (1/2)*(eden(P)+P)**2 - 2*sig(P,PCC)*(eden(P)+P) 
    Pcorr = P - (KN/4)*ctilde*Pcorr0
    return (4*PI*r**3*Pcorr+MSS*m)*2*GS/(2*r*(r-2*GS*MSS*m))*2*b

def P1(r,P,m,b,Lambda):
    return -(eden(P)+P) * b1(r,P,m,b,Lambda)/(2*b) -2*sig(P,PCC)/r

def m1(r,P,m,b,Lambda):
    edencorr0 = Lambda - (3/2)*(eden(P)+P)**2 + 2*sig(P,PCC)*(eden(P)+P) 
    edencorr = eden(P) + (KN/4)*ctilde*edencorr0
    return 4*PI*r**2*edencorr/MSS

def L1(r,P,m,b,Lambda):
    ed = eden(P)
    dsde=1/dedP(P)-dPTde(ed)
    sigprime = dsdP(P,PCC)*P1(r,P,m,b,Lambda)
    sigprime = sigprime + dsde*dedP(P)*P1(r,P,m,b,Lambda)
    Lambda1 = P1(r,P,m,b,Lambda)*(eden(P)+P-2*sig(P,PCC))*(1-dedP(P))
    Lambda1 = Lambda1 + 8*sig(P,PCC)/r*(eden(P)+P-sig(P,PCC))
    Lambda1 = Lambda1 + 2*sigprime*(eden(P)+P)
    return Lambda1

# %%
# define the Runge-Kutta 4th order for the problem
# if we want to print the profile, set profile=1
# if we not, set profile=0
def RungeKutta(rCC,bCC,LCC,PCC,MCC,h,profile):
    # input initial values
    r0 = rCC
    b0 = bCC
    P0 = PCC
    m0 = MCC
    L0 = LCC
    while (P0 > 0.):
        if profile == 1:
            f0 = 1-2*GS*MSS*m0/r0
            print(r0/1000, b0, P0, m0, abs(L0/1.e+6), f0, file=open('profileSL.dat', 'a'))
        # calculate k1
        r01 = r0
        b01 = b0
        P01 = P0
        m01 = m0
        L01 = L0
        k1_b = h * b1(r01,P01,m01,b01,L01)
        k1_P = h * P1(r01,P01,m01,b01,L01)
        k1_m = h * m1(r01,P01,m01,b01,L01)
        k1_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k2
        r01 = r0 + h/2
        b01 = b0 + k1_b/2
        P01 = P0 + k1_P/2
        m01 = m0 + k1_m/2
        L01 = L0 + k1_L/2
        k2_b = h * b1(r01,P01,m01,b01,L01)
        k2_P = h * P1(r01,P01,m01,b01,L01)
        k2_m = h * m1(r01,P01,m01,b01,L01)
        k2_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k3
        r01 = r0 + h/2
        b01 = b0 + k2_b/2
        P01 = P0 + k2_P/2
        m01 = m0 + k2_m/2
        L01 = L0 + k2_L/2
        k3_b = h * b1(r01,P01,m01,b01,L01)
        k3_P = h * P1(r01,P01,m01,b01,L01)
        k3_m = h * m1(r01,P01,m01,b01,L01)
        k3_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k4
        r01 = r0 + h
        b01 = b0 + k3_b
        P01 = P0 + k3_P
        m01 = m0 + k3_m
        L01 = L0 + k3_L
        k4_b = h * b1(r01,P01,m01,b01,L01)
        k4_P = h * P1(r01,P01,m01,b01,L01)
        k4_m = h * m1(r01,P01,m01,b01,L01)
        k4_L = h * L1(r01,P01,m01,b01,L01)
        # calculate the next r0, P0, m0, and b0
        r0 = r0 + h
        b0 = b0 + (k1_b+2*k2_b+2*k3_b+k4_b)/6
        P0 = P0 + (k1_P+2*k2_P+2*k3_P+k4_P)/6
        m0 = m0 + (k1_m+2*k2_m+2*k3_m+k4_m)/6
        L0 = L0 + (k1_L+2*k2_L+2*k3_L+k4_L)/6
        f0 = 1-2*GS*MSS*m0/r0
        # print(P0)
    if profile == 1:
        f0 = 1-2*GS*MSS*m0/r0
        print(r0/1000, b0, P0, m0, abs(L0/1.e+6), f0, file=open('profileSL.dat', 'a'))
    # the results at the surface
    output = np.array([r0,b0,P0,m0,L0,f0])
    return output
# define for a single PCC

def single_PCC(x,radmassdata,profile):
    # define initial parameters
    rCC = 1.*10**(-12) # radius near center in m--the starting point
    rmax = 100000. # radius at far distances in m
    PCC = x # pressure at the center in MeV / fm^3
    MCC = (4*PI/3)*eden(PCC)*rCC**3/MSS # Mass at the center in MeV m^3 / fm^3
    bCC = 1-2*GS*MSS*MCC/rCC # metric function b(r) at the center
    LCC = 1.*10**(-12) # Lambda function at center

    h = 10. # h-step

    # calculate the surface values
    output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
    # print(output)

    # at the surface, b = 1-2Gm/r, which is different to the result
    rSurface=output[0]
    bSurface=output[1]
    mSurface=output[3]
    bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface

    # So, we redefine bCC as follows
    bCorrection=bSurfaceTarget/bSurface
    # print("cek bCC ",abs(bCorrection-1))

    # if abs(LSurface) not near 0, then recalculate
    LSurface=output[4]
    print(PCC, rSurface, mSurface, GS*MSS*mSurface/rSurface, bCorrection, LSurface)

    # if abs(bCorrection) not near 1, then recalculate
    while (abs(bCorrection-1)>10**(-3)):
        while (abs(LSurface)>10**(-1)):
            print("abs(LSurface)>10**(-1)")
            if ctilde==0:
                break
            LCC = LCC - LSurface
            output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
            LSurface=output[4]
            # print("cek LCC ",(LSurface))
            # print(output)
        print("abs(bCorrection-1)>10**(-3)")
        bCC=bCC*bCorrection
        output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
        rSurface=output[0]
        bSurface=output[1]
        mSurface=output[3]
        bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface
        bCorrection=bSurfaceTarget/bSurface

    rSurface=output[0]
    bSurface=output[1]
    mSurface=output[3]
    bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface
    bCorrection=bSurfaceTarget/bSurface
    LSurface=output[4]
    print(PCC, rSurface, mSurface, GS*MSS*mSurface/rSurface, bCorrection, LSurface)

    if profile == 1:
        output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,profile)
        # print(output)
    if radmassdata == 1:
        print(PCC, (eden(PCC)/1000), (rSurface/1000), mSurface, 
            2*GS*MSS*mSurface/rSurface, abs(LCC/1.e+6), 0.5*np.log(bCC),
            file=open('radmassSL.dat', 'a'))

    output2=np.array([PCC, (eden(PCC)/1000), (rSurface/1000), mSurface, GS*MSS*mSurface/rSurface])
    return output2

# %%
# PCC=500
# single_PCC(PCC,0,1)
# Out:
# 500 11280.0 2.8532073282779336 0.3738605874529783 0.08516057105318192 1315703.3408917708
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 500 10790.0 1.9947122496466285 0.27323999135190713 0.9999999998879223 -0.02292012569898816
# array([5.00000000e+02, 1.78497935e+00, 1.07900000e+01, 1.99471225e+00,
#        2.73239991e-01])

# %%
# this is for multiple PCC
for x in range(5, 501, 5):
    PCC=x
    if PCC==500:
        single_PCC(PCC,1,1)
    else:
        single_PCC(PCC,1,0)
# Out:
# 5 5060.000000000001 0.11914085360320098 0.03480131411216227 0.8948646734709902 2810.3321580504735
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 5 5050.000000000001 0.11833221284786513 0.034633554068737894 1.0004484990959193 -0.008886067787042151
# 10 6690.000000000001 0.28161468466830847 0.06221779738272568 0.8125769678930876 5823.739050828985
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 10 6680.000000000001 0.27980879354752036 0.06191136073248398 1.0006920900611926 0.001353542237765737
# 15 7730.000000000001 0.4435775972768092 0.0848155657095759 0.7451802430501198 9065.517762440291
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 15 7710.000000000001 0.43887815946452435 0.08413467932808646 1.0000000000000002 -0.018957818440490826
# 20 8460.0 0.5930370742626024 0.10360886934402022 0.6894373403550536 12511.027887443046
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 20 8430.0 0.5845207820548162 0.10248441701142884 1.0000000000000013 -0.05522556795095923
# 25 8990.0 0.7252528329961719 0.11923814061730581 0.6432416041925796 16131.581852357016
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 25 8970.0 0.716560276619611 0.11807167891350702 0.999999999999989 0.0922953072821393
# 30 9410.0 0.8463161433520514 0.13293166809029833 0.6030501660571418 20038.511852437063
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 30 9370.0 0.8305533046722531 0.1310126926418906 1.0000000000000002 -0.05725124114196234
# 35 9730.0 0.9516730289692651 0.14456407241060226 0.5689752859789599 24107.125278966072
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 35 9690.0 0.9330874924445146 0.14232593442868513 0.9999999999999933 0.008536368316647724
# 40 9990.0 1.0466957917498865 0.15486042355340565 0.5389683737842174 28399.06805331845
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 40 9950.0 1.0251443551342052 0.15228158791976606 0.9999999999999408 0.08682567302661326
# 45 10210.0 1.1343312707477093 0.1642100054444434 0.5119050716483746 32885.36155383395
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 45 10160.0 1.1068812563775474 0.16102480363908747 0.9999999999999973 0.01655933692527256
# 50 10380.0 1.2096507332625097 0.1722455824339582 0.4886707669571821 37634.16354413635
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 50 10330.0 1.178904694709931 0.1686800917432071 0.9999999999996848 0.0005019989673371583
# 55 10530.0 1.2802090356963276 0.17969581791054232 0.4673402444890796 42677.7025953024
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 55 10460.0 1.2400908653711307 0.17522952222045718 0.9999999999997792 -0.0007940151190410916
# 60 10650.0 1.3428194979624468 0.18636033556053236 0.4482103568725651 47669.218553844614
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 60 10580.0 1.29912599222642 0.18148931320750064 0.9999999999996486 -0.08634796790224897
# 65 10750.0 1.3992626099962886 0.1923872195276641 0.4310101517157584 52960.706340606754
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 65 10680.0 1.3518878357157191 0.18709184615933255 0.9999999999992716 -0.006254451038948616
# 70 10840.0 1.4524604291667786 0.19804344848474095 0.4150356911301538 58534.28309901458
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 70 10760.0 1.398131712376276 0.19205307628544144 1.0000000000004652 -0.0005814789252625019
# 75 10910.0 1.4987475117821014 0.20304354037081918 0.40096752570995 64509.7521598789
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 75 10830.0 1.4404218817449348 0.19658333860014576 0.999999999999686 -0.027538343285137046
# 80 10970.0 1.5420194224332127 0.20776322079167084 0.3876533660928119 70259.95113962363
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 80 10890.0 1.4798332764646955 0.20084931830695013 1.000000000000808 0.05037597790101245
# 85 11030.0 1.5842880545522844 0.21229711291299377 0.37521227380911676 76827.57926177823
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 85 10940.0 1.5145289538940012 0.2046188837926055 1.0000000000002551 -0.05991437801107935
# 90 11070.0 1.6199401406776806 0.21629017847126347 0.36406049848082317 83092.99080282255
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 90 10980.0 1.546140315248231 0.20812872187602066 1.0000000000010547 0.020065308396027604
# 95 11110.0 1.6551180198377071 0.22019140416254498 0.35332740090744846 89589.12778152629
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 95 11020.0 1.57709937958847 0.21152559203797575 1.0000000000001752 0.0004965007906605479
# 100 11150.0 1.689755660127423 0.22399302524713774 0.343056269065111 96440.8982858481
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 100 11050.0 1.6040033636362447 0.2145499657538919 0.9999999999999926 -0.025742861847028564
# 105 11180.0 1.7205043030212275 0.22745705534675645 0.3337074785168799 103478.83473981591
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 105 11070.0 1.6270043204642461 0.21723336931419807 0.9999999999999988 -0.00072826026953976
# 110 11200.0 1.7473123761449059 0.23058868001395322 0.32524243441035194 110698.17148620359
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 110 11090.0 1.6493788038237311 0.2198235999780539 0.9999999999996682 -0.07601849186382736
# 115 11220.0 1.7737365338308135 0.23365856614277725 0.3170340192934403 118004.5603174371
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 115 11110.0 1.6712992514070821 0.22234410146729022 0.9999999999994804 0.005398965468771166
# 120 11240.0 1.7996062301420064 0.23664461684906718 0.3092250579939081 125812.30898889224
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 120 11130.0 1.6923606559286923 0.22474146567719713 1.0000000000014313 0.09523862566235408
# 125 11260.0 1.8250974833794633 0.2395703838002196 0.301688370939071 133850.25373832538
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 125 11140.0 1.7095729647120768 0.2268234246706127 1.0000000000011044 -0.037672451925296
# 130 11270.0 1.84655993337901 0.24217256677299714 0.2950172807449234 142365.97408078564
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 130 11150.0 1.7260055226646418 0.22879828589286458 0.9999999999999867 0.05773252556762287
# 135 11280.0 1.8679316520711464 0.24475824726933568 0.288274625804663 150047.53363427208
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 135 11160.0 1.7428191017060486 0.23082007061271087 1.0000000000052796 0.0005484012598913068
# 140 11290.0 1.8888334000793519 0.24727782077677452 0.2818561210919756 158231.70251548864
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 140 11160.0 1.755546820355203 0.2325057377679886 0.9999999999962169 -0.018163514648357193
# 145 11300.0 1.9093748494249516 0.2497458078767196 0.2756600306697562 166617.71700986323
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 145 11170.0 1.7711168899785044 0.23435784962145056 0.9999999999996151 0.06110361454293667
# 150 11310.0 1.929465044134567 0.25215045890097654 0.2699561710591229 176523.98258458628
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 150 11170.0 1.7820240777041452 0.23580111125780126 1.000000000000061 -0.055763134535730785
# 155 11310.0 1.9457714435609195 0.2542814465085917 0.2645103295404886 184612.02189978407
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 155 11170.0 1.7938239661943842 0.2373624969054639 1.0000000000000664 0.00649389007379142
# 160 11310.0 1.961694636117026 0.2563623550601077 0.2594467956109856 193902.9673296586
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 160 11170.0 1.8045649707579332 0.23878376884213323 1.0000000000030407 0.09114543557830501
# 165 11320.0 1.9810561054769895 0.2586638881182814 0.2542430253915649 204520.20868768173
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 165 11170.0 1.8143347878574394 0.2400765312451065 1.0000000000021876 -0.024234521423018407
# 170 11320.0 1.9964485562259873 0.26067366015219673 0.2493786554109036 213538.96300082086
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 170 11170.0 1.8247282176187818 0.24145181136514945 0.999999999999948 0.04685383653523445
# 175 11320.0 2.0116741551324147 0.26266164656064717 0.24488301679416716 224210.67556795457
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 175 11170.0 1.8340157480688166 0.2426807566012769 1.0000000000001792 0.0005836548725142165
# 180 11320.0 2.026632557351663 0.2646147454493514 0.24041502815045393 234373.03090727938
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 180 11160.0 1.8400257804818105 0.24369418499273146 0.9999999999997258 0.008278614286481911
# 185 11320.0 2.041326346121566 0.26653329410827326 0.2360326609579894 244362.98624366205
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 185 11160.0 1.849214731079451 0.24491117545589994 1.0000000000017744 0.08791987516086408
# 190 11320.0 2.055923978815795 0.26843928779496024 0.23186835703388112 255329.8508461927
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 190 11160.0 1.8577598582295778 0.24604289753207875 0.9999999999999973 0.000630030216697719
# 195 11320.0 2.0701422727526126 0.27029575171939835 0.22769550228728885 265326.5749599351
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 195 11150.0 1.8631887402983693 0.24698321325011216 0.9999999999999943 0.031490636408953776
# 200 11320.0 2.084311461990272 0.27214580410790157 0.22372289518486854 276314.69646344957
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 200 11150.0 1.8713309188041645 0.2480625356862789 1.0000000000034963 0.0003994240915048408
# 205 11320.0 2.0985009404343127 0.2739985056313763 0.21992956604311617 288339.7944238436
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 205 11140.0 1.8756011181457617 0.24885177627121774 1.000000000000012 -0.0007163246276604696
# 210 11320.0 2.1122805360784462 0.2757976892971772 0.21612956538033076 299340.2375321392
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 210 11140.0 1.8833842666906075 0.24988443205374491 0.9999999999961011 0.08112581522041751
# 215 11320.0 2.1259042256211322 0.27757651650852416 0.2124323356573074 310534.2529816634
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 215 11130.0 1.8876132173873825 0.2506705409518601 0.9999999999988247 -0.058023821520443164
# 220 11320.0 2.1396164457606783 0.27936690304337436 0.20889069938600982 322794.97309543943
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 220 11130.0 1.8946376180615576 0.251603364636627 0.9999999999927919 0.03918766230831494
# 225 11320.0 2.153227846581983 0.28114412573254566 0.20543405623652003 335279.4070251516
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 225 11120.0 1.898152883294956 0.2522968653096284 0.9999999999903358 -0.08360999773830713
# 230 11310.0 2.162750492576892 0.2826371645598689 0.20245725317125401 347473.80645602586
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 230 11110.0 1.901598982206092 0.25298241275089434 0.9999999999955496 0.0022385773957012134
# 235 11310.0 2.176163182838388 0.28438999030543705 0.19915766835659943 360396.97666341835
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 235 11110.0 1.9080128270415064 0.25383568936528894 1.000000000000215 0.0003472055557836029
# 240 11310.0 2.1892024933606495 0.2860940212449638 0.1958901670465286 372608.0745467418
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 240 11100.0 1.9111948243092367 0.2544880738860327 0.9999999999982639 -0.03338389512789064
# 245 11310.0 2.2022986166850402 0.2878054767160579 0.19272008196916435 385486.55108065624
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 245 11090.0 1.9140737126312168 0.255101237604433 1.0000000000070908 -0.0006441727920076801
# 250 11300.0 2.211074011794197 0.2892079915670146 0.18999558919797185 397544.0974751435
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 250 11090.0 1.9202822975950067 0.255928696702577 1.0000000000007305 0.0004122895151397188
# 255 11300.0 2.224677711477826 0.2909873524759652 0.18702855643910876 412783.59902719734
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 255 11080.0 1.922373915294233 0.25643869456919666 0.9999999999981661 0.03629380159414097
# 260 11300.0 2.237031472498903 0.29260322168438907 0.18401351953391615 424803.92647145485
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 260 11070.0 1.9250811491954212 0.2570318093092978 1.000000000000016 -0.00040400719902322635
# 265 11300.0 2.250211754826646 0.29432719969686616 0.1811343415264302 439514.6073526839
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 265 11070.0 1.9303621824610744 0.25773691908394847 1.000000000000624 0.001916363735062987
# 270 11300.0 2.263370489945882 0.29604835933923773 0.17830903563282186 454463.0033104004
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 270 11060.0 1.932242026218967 0.2582211730404716 0.9999999999980003 -0.0003382161939384787
# 275 11290.0 2.272120338809141 0.297456073097663 0.17590978567643814 468541.8695242141
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 275 11050.0 1.9341904431568921 0.2587154757581452 1.000000000003525 -0.01465261643186011
# 280 11290.0 2.2831682161407945 0.2989024129551992 0.1731006304261411 478660.26692030556
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 280 11050.0 1.9400209046228265 0.25949535274357105 0.9999999999840559 0.026558180479241855
# 285 11290.0 2.2974652987488446 0.300774124579229 0.1704803598824195 497446.6279230163
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 285 11040.0 1.9409370501883203 0.2598530566410977 1.0000000000071165 -0.0349165117205672
# 290 11280.0 2.3051815372734064 0.3020518401061828 0.1682049578337198 509966.158670848
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 290 11030.0 1.9428584287170096 0.2603461119523859 0.9999999999973598 0.0280831675661517
# 295 11280.0 2.31774246769488 0.30369772008825985 0.1656185727938344 524903.2144421677
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 295 11030.0 1.9475264232689664 0.2609716306285045 1.000000000026966 0.00028742326036024224
# 300 11280.0 2.3302846333972482 0.30534114129741885 0.1630789284730114 540046.3167089783
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 300 11020.0 1.9488383531724849 0.26138440720754774 0.999999999998611 0.01242581592833858
# 305 11280.0 2.3428124953801226 0.3069826882659927 0.16058416780534454 555395.3701316032
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 305 11010.0 1.9500409216605457 0.26178325238409156 0.9999999999968695 -0.09928363781148164
# 310 11270.0 2.3512274105923336 0.30835867647589754 0.158507242186817 570884.4895474327
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 310 11010.0 1.9543641236477287 0.26236362065449403 0.9999999999966438 0.00044568178486770194
# 315 11270.0 2.363721536708167 0.3099972556177726 0.15609434044666098 586645.0336828853
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 315 11000.0 1.955356126593917 0.26273542554186874 0.9999999999901352 0.09279394673991703
# 320 11270.0 2.376213331388549 0.3116355289966461 0.15372130852768667 602611.2755998806
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 320 10990.0 1.9562506852651773 0.26309480184009365 0.9999999999951272 -0.015229871125498562
# 325 11270.0 2.3887065325895183 0.31327398683782426 0.15138660531758624 618783.1366366147
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 325 10980.0 1.9570515789985483 0.2634422243346144 1.000000000025612 -0.0004432418586333142
# 330 11270.0 2.4012047210778436 0.314913098751561 0.14908875833151022 635160.5416471825
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 330 10980.0 1.9609714786996406 0.26396988906634966 1.0000000000041311 -0.019785121714733123
# 335 11270.0 2.4148000542132855 0.31669609894669637 0.14680947109485387 654197.2417858938
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 335 10970.0 1.9613005433724449 0.2642548543185824 0.9999999999973472 -0.09697190221838525
# 340 11260.0 2.422018397817553 0.317924868353842 0.14495836340401666 668464.8209324192
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 340 10970.0 1.9653282263785459 0.26479752218741837 1.000000000035422 0.0006290497480563317
# 345 11260.0 2.435097496372122 0.31964168879166155 0.14274840176107711 686715.7937577058
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 345 10960.0 1.9656405150005485 0.2650812402089528 1.0000000000021863 0.08817365868256388
# 350 11260.0 2.44764014249107 0.3212880921054302 0.14058034306780448 703929.9314510695
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 350 10950.0 1.9660163673518383 0.2653740563068303 0.99999999999842 -0.012755439531417778
# 355 11260.0 2.4590275029117312 0.3227828474986587 0.13847441808507333 718773.2098156111
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 355 10950.0 1.9697716751272496 0.2658809499795335 1.000000000000105 0.06462769111983846
# 360 11260.0 2.473388489723369 0.3246679342699381 0.13631697506171825 740277.614266659
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 360 10940.0 1.969602031284971 0.26610106602517 1.000000000000002 0.007554674096752478
# 365 11260.0 2.4841816274393236 0.3260846893575798 0.13429331258517813 754165.9267707483
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 365 10930.0 1.970138410728221 0.2664170586685007 1.000000000003407 -0.00044951454852082406
# 370 11260.0 2.496800368870905 0.3277410812793099 0.13224400567943473 772169.8873584473
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 370 10930.0 1.9733983062317335 0.2668578864635851 0.9999999999964732 -0.022526294912879052
# 375 11260.0 2.510713430115454 0.329567371355619 0.13017553784632893 793077.7366434433
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 375 10920.0 1.973168309635716 0.26707113145175815 1.0000000000509899 -0.090218941796266
# 380 11260.0 2.5240606785306254 0.33131939033247854 0.1281500613688319 812887.557916992
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 380 10920.0 1.9761761381707488 0.26747824531332853 0.9999999999999988 0.032321741877495924
# 385 11260.0 2.536811647955976 0.33299313908665457 0.12617165955398932 831552.4042698895
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 385 10910.0 1.9760681085622545 0.2677087779110066 1.000000000003078 -0.059198214284450046
# 390 11250.0 2.543856610413968 0.334214707983532 0.12461142130903533 847562.3490042749
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 390 10900.0 1.9761286132019908 0.2679625867096823 1.000000000029676 0.013105833990422866
# 395 11250.0 2.5559701606395437 0.33580619967166836 0.12270901272837627 865195.3885843641
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 395 10900.0 1.9791725625144363 0.2683753455382964 1.0000000000073412 1.7527925905369557e-05
# 400 11250.0 2.5701508999896325 0.33766928096386006 0.12074080606988147 887280.8427553781
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 400 10890.0 1.9786655275869616 0.26855297059052463 0.9999999999890063 0.04873737981867521
# 405 11250.0 2.583031848114157 0.3393615942406247 0.11885107575555684 906749.3771329995
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 405 10890.0 1.9814822430331727 0.26893526728991207 0.9999999999802477 0.0006189531580105267
# 410 11250.0 2.595255712876738 0.34096757917520454 0.11701469430229648 924965.598620183
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 410 10880.0 1.9811940548275369 0.26914330035038186 1.0000000000032812 0.06127966422383224
# 415 11250.0 2.6082194447636597 0.34267076867465485 0.11516619983345157 944828.095764185
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 415 10870.0 1.980749451357436 0.2693304477654752 1.0000000000071148 -0.023425584776987307
# 420 11250.0 2.6212323888997906 0.3443804237340865 0.11333653458021895 964895.1840982221
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 420 10870.0 1.9834012550992028 0.26969102415673296 0.9999999999989779 0.09088769330806201
# 425 11260.0 2.640346885793117 0.3465836332336096 0.11112273009909798 988241.9178279685
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 425 10860.0 1.9826611613367122 0.2698386322513085 1.0000000000086362 -0.00032694070580419066
# 430 11250.0 2.646670019151036 0.3477224478605288 0.10976941836727598 1004124.9237282601
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 430 10860.0 1.9855056907137643 0.2702257704731441 0.999999999991392 0.0003492021374285059
# 435 11260.0 2.665968008451561 0.3499467753367428 0.10758944444172545 1027926.2130737664
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 435 10850.0 1.9846794558134133 0.2703622729190615 0.9999999999999938 -0.00028038059909363255
# 440 11260.0 2.677699735812587 0.3514867338606657 0.10591106894113231 1045728.9298692746
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 440 10850.0 1.9873225008750481 0.27072232081908787 1.0000000000321918 -0.033217952348138624
# 445 11260.0 2.691773462194498 0.3533341135549112 0.10412623284020997 1068367.19220617
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 445 10840.0 1.9865084118858372 0.27086106336095134 0.999999999996575 -0.09567391393700575
# 450 11260.0 2.705925832647279 0.3551918164184193 0.10235398849675595 1091240.7547119393
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 450 10840.0 1.9887839037007482 0.27117132740462124 0.999999999998627 0.038217820267504976
# 455 11260.0 2.7185695874473153 0.3568514917057425 0.10068346635648973 1111159.2948843932
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 455 10830.0 1.9880714049661745 0.27132447730541936 0.9999999999912861 -0.04873477061521214
# 460 11260.0 2.7328632860170776 0.35872774592419765 0.09893738934691969 1134472.120068738
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 460 10830.0 1.9902653853890788 0.27162390346786797 1.0000000000264457 0.08698245812617245
# 465 11260.0 2.7456122787403285 0.36040123520769607 0.09729673742325692 1154768.5491550528
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 465 10820.0 1.9894732861683073 0.27176673957532244 0.9999999999999997 0.0014013327768793715
# 470 11270.0 2.764871278165692 0.3626072255369852 0.09526068339430907 1178589.5788422744
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 470 10820.0 1.9915902686965747 0.2720559243778755 0.9999999999342039 -0.03875691084849109
# 475 11270.0 2.776920895388957 0.36418750824476076 0.0936987620874845 1197607.7880078831
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 475 10810.0 1.9908053317473628 0.2722002715562019 0.9999999999908112 -0.0002733943307333675
# 480 11270.0 2.7906883217486635 0.3659930781150479 0.09205206803060839 1220111.8316209288
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 480 10810.0 1.9929288973180417 0.272490623965746 0.9999999999850062 -0.008899091457294617
# 485 11270.0 2.8062317911895396 0.36803157241085255 0.09031353466509334 1246193.5766110441
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 485 10800.0 1.991750644125922 0.2725816798765988 1.0000000000003053 -0.04597147863832163
# 490 11270.0 2.819291982096655 0.3697443897948699 0.08874019984751652 1267434.1852243096
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 490 10800.0 1.9938837102014013 0.27287360132562993 1.000000000094028 0.06805165440574967
# 495 11280.0 2.8391128635634004 0.3720137658758057 0.08676451620033047 1292352.3845276712
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 495 10790.0 1.99272475836908 0.27296774050490624 1.000000000013806 -0.00045889914747476723
# 500 11280.0 2.8532073282779336 0.3738605874529783 0.08516057105318192 1315703.3408917708
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 500 10790.0 1.9947122496466285 0.27323999135190713 0.9999999998879223 -0.02292012569898816
