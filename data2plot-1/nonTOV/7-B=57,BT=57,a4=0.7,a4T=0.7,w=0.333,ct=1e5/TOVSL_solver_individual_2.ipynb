# %%
# deleting profile and radmass files
import os

if os.path.exists('profileSL.dat'):
    os.remove('profileSL.dat')

if os.path.exists('radmassSL.dat'):
    os.remove('radmassSL.dat')

# %%
# source: https://www.codesansar.com/numerical-methods/
#         runge-kutta-fourth-order-rk4-python-program.htm

import cmath #To help us out with the complex square root
import numpy as np #For the arrays
import matplotlib.pyplot as plt #Visualization

# deleting profile and radmass files
# os.remove("radmass.txt")
# os.remove("profile.txt")

# some constants
GS = 1.325 * 10**(-12) # Newton constant in fm^3 / MeV m^2
MSS = 1.1155 * 10**(15) # Sun's mass in MeV m^3 / fm^3
PI = np.pi 
HC = 197.327 # hc=1=197.327 MeV fm
KN = 8*PI*GS

# constants in eden
B = 57 # MeV
w = 1/3. # speed of sound
a4 = 0.7 # don't know, dimensionless
ms = 100 # quark mass in MeV

# additional constants for tangential pressure
BT = 57 # MeV
a4t = 0.7 # don't know, dimensionless

# constants for SL model
ctilde = 1.e5 # meter^2

# masalah satuan 
alpha = ms**2/(3*PI*np.sqrt(a4))*HC**(-1.5)
beta = ms**4/(12*PI**2)*(1-1/a4)*HC**(-3)
gamma = 8*PI/(3*ms**2*np.sqrt(a4))*HC**(1.5)
kappa = 3/(1-1/a4)

alphat = ms**2/(3*PI*np.sqrt(a4t))*HC**(-1.5)
betat = ms**4/(12*PI**2)*(1-1/a4t)*HC**(-3)
gammat = 8*PI/(3*ms**2*np.sqrt(a4t))*HC**(1.5)
kappat = 3/(1-1/a4t)

# %%
# define energy density as function of pressure

def eden(P):
    sqdoe = alpha**2 + 4*w*P + 12*w**2*B
    doeden = alpha**2/(2*w**2) + alpha/(2*w**2)*np.sqrt(sqdoe)
    lgPt = gamma*np.sqrt(P/w + 3*B + doeden)
    Ptilde = P - beta*(1+kappa*np.log(lgPt))
    sqde = alpha**2 + 4*w*Ptilde + 12*w**2*B
    deden = alpha**2/(2*w**2) + alpha/(2*w**2)*np.sqrt(sqde)
    # print("cek eden: ",sqdoe,doeden,lgPt,Ptilde,sqde,deden)
    return P/w + 4*B + deden

def dedP(P):
    dP = 0.00001
    x1 = P-2*dP
    x2 = P-dP
    x3 = P+dP
    x4 = P+2*dP
    dedP = eden(x1) - 8*eden(x2) + 8*eden(x3) - eden(x4)
    dedP = dedP/(12*dP)
    return dedP

# define tangential pressure

def fpt(ed,PCC):
    fpt = PCC + w*(ed-4*BT) - alphat*np.sqrt(ed-BT)
    fpt = fpt + betat*(1+kappat*np.log(gammat*np.sqrt(ed-BT)))
    fpt = fpt - w*(eden(PCC)-4*BT) + alphat*np.sqrt(eden(PCC)-BT)
    fpt = fpt - betat*(1+kappat*np.log(gammat*np.sqrt(eden(PCC)-BT)))
    return fpt

def dPTde(ed):
    return w-(1/2)*alphat/np.sqrt(ed-BT)+(1/2)*betat*kappat/(ed-BT)

# define sigma

def sig(P,PCC):
    ed = eden(P)
    Ptan = fpt(ed,PCC)
    sig = P - Ptan
    return sig

def dsdP(P,PCC):
    dP = 0.00001
    x1 = P-2*dP
    x2 = P-dP
    x3 = P+dP
    x4 = P+2*dP
    dsdP = sig(x1,PCC) - 8*sig(x2,PCC) + 8*sig(x3,PCC) - sig(x4,PCC)
    dsdP = dsdP/(12*dP)
    return dsdP


# the TOV SL equation

def b1(r,P,m,b,Lambda):
    Pcorr0 = Lambda - (1/2)*(eden(P)+P)**2 - 2*sig(P,PCC)*(eden(P)+P) 
    Pcorr = P - (KN/4)*ctilde*Pcorr0
    return (4*PI*r**3*Pcorr+MSS*m)*2*GS/(2*r*(r-2*GS*MSS*m))*2*b

def P1(r,P,m,b,Lambda):
    return -(eden(P)+P) * b1(r,P,m,b,Lambda)/(2*b) -2*sig(P,PCC)/r

def m1(r,P,m,b,Lambda):
    edencorr0 = Lambda - (3/2)*(eden(P)+P)**2 + 2*sig(P,PCC)*(eden(P)+P) 
    edencorr = eden(P) + (KN/4)*ctilde*edencorr0
    return 4*PI*r**2*edencorr/MSS

def L1(r,P,m,b,Lambda):
    ed = eden(P)
    dsde=1/dedP(P)-dPTde(ed)
    sigprime = dsdP(P,PCC)*P1(r,P,m,b,Lambda)
    sigprime = sigprime + dsde*dedP(P)*P1(r,P,m,b,Lambda)
    Lambda1 = P1(r,P,m,b,Lambda)*(eden(P)+P-2*sig(P,PCC))*(1-dedP(P))
    Lambda1 = Lambda1 + 8*sig(P,PCC)/r*(eden(P)+P-sig(P,PCC))
    Lambda1 = Lambda1 + 2*sigprime*(eden(P)+P)
    return Lambda1

# %%
# define the Runge-Kutta 4th order for the problem
# if we want to print the profile, set profile=1
# if we not, set profile=0
def RungeKutta(rCC,bCC,LCC,PCC,MCC,h,profile):
    # input initial values
    r0 = rCC
    b0 = bCC
    P0 = PCC
    m0 = MCC
    L0 = LCC
    while (P0 > 0.):
        if profile == 1:
            f0 = 1-2*GS*MSS*m0/r0
            print(r0/1000, b0, P0, m0, L0/1.e+6, f0, file=open('profileSL.dat', 'a'))
        # calculate k1
        r01 = r0
        b01 = b0
        P01 = P0
        m01 = m0
        L01 = L0
        k1_b = h * b1(r01,P01,m01,b01,L01)
        k1_P = h * P1(r01,P01,m01,b01,L01)
        k1_m = h * m1(r01,P01,m01,b01,L01)
        k1_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k2
        r01 = r0 + h/2
        b01 = b0 + k1_b/2
        P01 = P0 + k1_P/2
        m01 = m0 + k1_m/2
        L01 = L0 + k1_L/2
        k2_b = h * b1(r01,P01,m01,b01,L01)
        k2_P = h * P1(r01,P01,m01,b01,L01)
        k2_m = h * m1(r01,P01,m01,b01,L01)
        k2_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k3
        r01 = r0 + h/2
        b01 = b0 + k2_b/2
        P01 = P0 + k2_P/2
        m01 = m0 + k2_m/2
        L01 = L0 + k2_L/2
        k3_b = h * b1(r01,P01,m01,b01,L01)
        k3_P = h * P1(r01,P01,m01,b01,L01)
        k3_m = h * m1(r01,P01,m01,b01,L01)
        k3_L = h * L1(r01,P01,m01,b01,L01)
        # calculate k4
        r01 = r0 + h
        b01 = b0 + k3_b
        P01 = P0 + k3_P
        m01 = m0 + k3_m
        L01 = L0 + k3_L
        k4_b = h * b1(r01,P01,m01,b01,L01)
        k4_P = h * P1(r01,P01,m01,b01,L01)
        k4_m = h * m1(r01,P01,m01,b01,L01)
        k4_L = h * L1(r01,P01,m01,b01,L01)
        # calculate the next r0, P0, m0, and b0
        r0 = r0 + h
        b0 = b0 + (k1_b+2*k2_b+2*k3_b+k4_b)/6
        P0 = P0 + (k1_P+2*k2_P+2*k3_P+k4_P)/6
        m0 = m0 + (k1_m+2*k2_m+2*k3_m+k4_m)/6
        L0 = L0 + (k1_L+2*k2_L+2*k3_L+k4_L)/6
        f0 = 1-2*GS*MSS*m0/r0
        # print(P0)
    if profile == 1:
        f0 = 1-2*GS*MSS*m0/r0
        print(r0/1000, b0, P0, m0, L0/1.e+6, f0, file=open('profileSL.dat', 'a'))
    # the results at the surface
    output = np.array([r0,b0,P0,m0,L0,f0])
    return output
# define for a single PCC

def single_PCC(x,radmassdata,profile):
    # define initial parameters
    rCC = 1.*10**(-12) # radius near center in m--the starting point
    rmax = 100000. # radius at far distances in m
    PCC = x # pressure at the center in MeV / fm^3
    MCC = (4*PI/3)*eden(PCC)*rCC**3/MSS # Mass at the center in MeV m^3 / fm^3
    bCC = 1-2*GS*MSS*MCC/rCC # metric function b(r) at the center
    LCC = 1.*10**(-12) # Lambda function at center

    h = 10. # h-step

    # calculate the surface values
    output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
    # print(output)

    # at the surface, b = 1-2Gm/r, which is different to the result
    rSurface=output[0]
    bSurface=output[1]
    mSurface=output[3]
    bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface

    # So, we redefine bCC as follows
    bCorrection=bSurfaceTarget/bSurface
    # print("cek bCC ",abs(bCorrection-1))

    # if abs(LSurface) not near 0, then recalculate
    LSurface=output[4]
    print(PCC, rSurface, mSurface, GS*MSS*mSurface/rSurface, bCorrection, LSurface)

    # if abs(bCorrection) not near 1, then recalculate
    while (abs(bCorrection-1)>10**(-3)):
        while (abs(LSurface)>10**(-1)):
            print("abs(LSurface)>10**(-1)")
            if ctilde==0:
                break
            LCC = LCC - LSurface
            output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
            LSurface=output[4]
            # print("cek LCC ",(LSurface))
            # print(output)
        print("abs(bCorrection-1)>10**(-3)")
        bCC=bCC*bCorrection
        output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,0)
        rSurface=output[0]
        bSurface=output[1]
        mSurface=output[3]
        bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface
        bCorrection=bSurfaceTarget/bSurface

    rSurface=output[0]
    bSurface=output[1]
    mSurface=output[3]
    bSurfaceTarget = 1-2*GS*MSS*mSurface/rSurface
    bCorrection=bSurfaceTarget/bSurface
    LSurface=output[4]
    print(PCC, rSurface, mSurface, GS*MSS*mSurface/rSurface, bCorrection, LSurface)

    if profile == 1:
        output=RungeKutta(rCC,bCC,LCC,PCC,MCC,h,profile)
        # print(output)
    if radmassdata == 1:
        print(PCC, (eden(PCC)/1000), (rSurface/1000), mSurface, 
            2*GS*MSS*mSurface/rSurface, LCC/1.e+6, 0.5*np.log(bCC),
            file=open('radmassSL.dat', 'a'))

    output2=np.array([PCC, (eden(PCC)/1000), (rSurface/1000), mSurface, GS*MSS*mSurface/rSurface])
    return output2

# %%
# this is for multiple PCC
for x in range(5, 501, 5):
    PCC=x
    if PCC==500:
        single_PCC(PCC,1,1)
    else:
        single_PCC(PCC,1,0)
# Out:
# 5 5050.000000000001 0.12225779802400068 0.03578249705879185 0.8930011975554287 2808.5088964810807
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 5 5050.000000000001 0.12225659217338533 0.03578214412959801 1.0000001175540771 0.0428209639219812
# 10 6670.000000000001 0.2883037811187015 0.06388662666945016 0.8094575491904752 5825.402083094567
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 10 6670.000000000001 0.2882977502195937 0.06388529025340219 1.0000008047782418 4.422119481262143e-06
# 15 7690.000000000001 0.4515137762849356 0.08678209273286674 0.7417295703376328 9058.139476347784
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 15 7690.000000000001 0.4514989134855718 0.08677923606514051 1.000002373572835 1.0095732264403523e-05
# 20 8400.0 0.6006697108920727 0.10569194735864781 0.6859943793497366 12493.04509647733
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 20 8400.0 0.6006423071975265 0.10568712549100762 1.0000049621458822 1.999886600856371e-05
# 25 8930.0 0.7356471308416318 0.12175969161829094 0.6388081100500004 16148.956860809747
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 25 8930.0 0.7356037227999971 0.12175250699193735 1.000008664618676 2.9320540793520422e-05
# 30 9320.0 0.8519159217434926 0.1351033990540716 0.5996307879036796 20021.000972970767
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 30 9320.0 0.8518538161769145 0.13509354987420452 1.0000133989761666 4.1096257298534056e-05
# 35 9630.0 0.9562690081876015 0.14677065983271878 0.5654513884899447 24104.818345994267
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 35 9630.0 0.9561855246664781 0.1467578465643021 1.000019242759193 5.524131358924933e-05
# 40 9880.0 1.049723830119266 0.1570375693886543 0.5354309785281489 28414.51920779464
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 40 9880.0 1.0496165256611836 0.15702151675576329 1.000026194581285 6.713437725736071e-05
# 45 10080.0 1.1324696083561019 0.16605481634530075 0.5090547458457922 32888.29233528362
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 45 10080.0 1.1323366946470956 0.1660353271145294 1.000034125348263 8.100931299992453e-05
# 50 10230.0 1.2022068804114663 0.17369568445808037 0.4865836231516904 37621.48528400015
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 50 10230.0 1.2020470088923538 0.17367258611004224 1.0000428781318413 9.045464084067589e-05
# 55 10360.0 1.266556121155742 0.18069666437478085 0.4660641657840156 42648.5436275832
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 55 10360.0 1.2663669738860928 0.18066967916652177 1.0000527886856492 0.00010299459199103467
# 60 10470.0 1.3257043861359163 0.18714811811111406 0.4471389628193172 47657.83939167105
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 60 10470.0 1.3254853493232293 0.18711719694368023 1.0000634358064704 0.00012043352914758998
# 65 10560.0 1.3783079331502859 0.19291579656663024 0.4301963749259443 52968.28900027545
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 65 10560.0 1.3780573779444296 0.19288072743878215 1.000075035492899 0.00012526035953186465
# 70 10630.0 1.4241479516291426 0.19801919831195283 0.41512132766604204 58521.6704541076
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 70 10630.0 1.423864913341752 0.19797984354217868 1.0000873760045141 0.0001437639212014119
# 75 10690.0 1.4658117364735703 0.20266835495304528 0.4014037257301436 64516.69829572037
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 75 10690.0 1.4654938044101913 0.20262439653282763 1.000100912109383 0.00015620603227972651
# 80 10740.0 1.504510552228431 0.20705056008746084 0.38841728449694135 70285.79933294914
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 80 10740.0 1.5041588064799842 0.20700215288013585 1.0001146651680393 0.00015971911768275504
# 85 10780.0 1.538232867687462 0.21090592413493567 0.3769729671390382 76831.24790409762
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 85 10770.0 1.5346196185020209 0.21060588155818757 0.999999999999996 -0.0019600544700040246
# 90 10810.0 1.5688045431205357 0.21450064245166683 0.3662022193929078 83114.7494720372
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 90 10810.0 1.5683797023201933 0.21444255451138597 1.0001451023985928 0.00018725426849641735
# 95 10830.0 1.595346692092102 0.21772689163555675 0.3564334726525981 89583.31433498306
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 95 10830.0 1.594886068970291 0.21766402753145667 1.0001606944808934 0.0001900658549658374
# 100 10850.0 1.620937857839713 0.22081169945223633 0.3471462512397381 96407.30744553827
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 100 10850.0 1.6204393070747216 0.22074378454658555 1.0001774524160403 0.00019654518073508598
# 105 10870.0 1.6458015061308608 0.2237862321635595 0.33823645139015507 103463.92957074184
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 105 10870.0 1.6452634999831597 0.22371307730969264 1.0001952072210667 0.00020025265618528465
# 110 10880.0 1.6666752713074588 0.22641622714293178 0.330224216449136 110700.54958354823
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 110 10880.0 1.6660981606664584 0.22633782721930606 1.0002131544704536 0.00020698565148791204
# 115 10890.0 1.6870211541880906 0.2289697455632029 0.3224706828501507 118024.97305532514
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 115 10890.0 1.6864043699106412 0.22888603295608803 1.000231758031227 0.00021985555575554372
# 120 10890.0 1.7030949002210582 0.23115134330445194 0.31568582010255464 125799.95304727771
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 120 10890.0 1.7024377932461823 0.23106215792792503 1.0002507965727507 0.000251447618232703
# 125 10890.0 1.7185470153837727 0.23324857063822707 0.3091749108512994 133804.3111563986
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 125 10890.0 1.7178484917390544 0.23315376401366045 1.0002706292827424 0.00023642422830505438
# 130 10890.0 1.7331241384808453 0.23522704029659156 0.3030424865501149 142337.37557504885
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 130 10890.0 1.7323815399032458 0.2351262516331261 1.0002917938363924 0.00026341489866865686
# 135 10890.0 1.7481039671768532 0.23726016688578122 0.2967466860716017 150034.5271435979
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 135 10890.0 1.747321807687517 0.23715400884572432 1.0003118219272338 0.00026602515463736154
# 140 10890.0 1.7622292330881013 0.23917730854916933 0.29081667296618974 158235.65587822103
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 140 10890.0 1.7614049982420954 0.23906543986127185 1.0003331075427797 0.0002913890960414278
# 145 10880.0 1.7725169574086317 0.24079471805476654 0.2856122485984273 166582.4805485771
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 145 10880.0 1.7716523851441628 0.24067726674701426 1.0003538456227665 0.0002732967153704635
# 150 10880.0 1.7846168445481823 0.24243847604539367 0.280536299892861 176509.0760922293
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 150 10880.0 1.7837015495220805 0.2423141340994248 1.000378999847833 0.0002559937956476688
# 155 10870.0 1.7943950213205202 0.243991088438365 0.27553408662304885 184609.728358001
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 155 10870.0 1.7934413113795833 0.24386140867232753 1.0003997281386847 0.0002853595598253378
# 160 10860.0 1.8030041310758949 0.24538745104835058 0.27101633806521314 193915.81678299687
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 160 10860.0 1.8020060858832139 0.24525161787878547 1.000422944108553 0.0002422313119154751
# 165 10850.0 1.810543501874344 0.24664066277894936 0.2669419919837888 204495.19571726164
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 165 10850.0 1.809494907153938 0.24649781832557954 1.000448828266992 0.0003126377987072715
# 170 10840.0 1.8187534615398058 0.24798762171684874 0.2625727506833638 213527.56923707647
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 170 10840.0 1.8176627532552438 0.24783890329008273 1.0004718556516128 0.0003239976238944564
# 175 10830.0 1.8257487815508053 0.24917129868064614 0.258708709652658 224216.216526929
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 175 10830.0 1.8246078036849722 0.24901558233047336 1.000498310434202 0.00032338760215111506
# 180 10820.0 1.832784641506947 0.2503627014391242 0.2548163162377354 234394.22010277014
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 180 10820.0 1.831596456224365 0.2502003925292716 1.0005239045937728 0.00030460718630109795
# 185 10810.0 1.8396501950946305 0.251533022685678 0.25098461189038357 244399.24264296153
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 185 10800.0 1.8351753022871997 0.2511535107272515 1.0000000000000004 -0.0019381390699635404
# 190 10790.0 1.8425701631757785 0.25239923981046514 0.2478869850962767 255320.18165957386
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 190 10790.0 1.8412893828175623 0.2522237957512708 1.0005748463354756 0.0003066313276676169
# 195 10780.0 1.8489393968648715 0.25350665712371634 0.24424072149133594 265330.9704632589
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 195 10780.0 1.8476136442664732 0.25332488420570565 1.0006003773718755 0.0003411171882561348
# 200 10770.0 1.8546438202995892 0.2545248946653717 0.24086788611715407 276334.9148772004
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 200 10760.0 1.85005127256444 0.2541305908710932 0.9999999999999974 -0.001915203180189451
# 205 10750.0 1.8565193373711826 0.2552562976846287 0.2381776961192428 288313.1978373766
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 205 10750.0 1.8550938029777246 0.2550602983087151 1.0006557856055496 0.0002401199435411172
# 210 10740.0 1.861819988234813 0.2562234414209136 0.23495266257243816 299328.46423516073
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 210 10740.0 1.8603458351807018 0.25602056865604245 1.0006835626322783 0.0004097518737893324
# 215 10730.0 1.8668396160236784 0.2571536774434853 0.2318365516406582 310537.4050878158
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 215 10720.0 1.862123741718072 0.2567433507369053 0.9999999999999898 -0.0018139713360341148
# 220 10710.0 1.8681130473011895 0.2578096300794053 0.2293666618233956 322748.93425904127
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 220 10710.0 1.8665403026151233 0.2575925828689542 1.0007399678296853 0.0003556504205590727
# 225 10700.0 1.8723459174860355 0.2586352784127351 0.2265681650973102 335249.85258276656
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 225 10700.0 1.8707186572982164 0.2584104978912534 1.0007709508940286 0.00029064781536192186
# 230 10680.0 1.8733136195191529 0.2592535373511273 0.22420555571653436 347454.35515597614
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 230 10680.0 1.8716383170357391 0.2590216871737557 1.0007989666874018 0.0002480486487854705
# 235 10670.0 1.8771039519061483 0.26002155879245387 0.22157623949932279 360394.19191882026
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 235 10670.0 1.8753730739573276 0.259781792858407 1.0008308823835157 0.000427082589808947
# 240 10650.0 1.8777824044652514 0.26060401977838576 0.21931463017237401 372552.35312549304
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 240 10650.0 1.8760050628397784 0.2603573552175632 1.0008586187058222 0.0004548378040425405
# 245 10640.0 1.8812848898724817 0.2613354901705731 0.21678692571326363 385446.42768854357
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 245 10640.0 1.879453291534239 0.261081056803199 1.000890399960015 0.0003066078445073117
# 250 10620.0 1.8816856486414335 0.2618834229664654 0.21462197321654672 397511.67083701707
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 250 10620.0 1.8798093570983172 0.26162229026762746 1.000917711434214 0.00034862724341166995
# 255 10610.0 1.8843379156004607 0.2624997268547894 0.21245175847010928 412770.66750927235
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 255 10610.0 1.882397099352769 0.26222935935293284 1.0009544652865754 0.0004069590868596151
# 260 10590.0 1.8844910881997587 0.26301685521955154 0.21037222311377576 424734.2615613906
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# 260 10590.0 1.8825074272388984 0.26273999730761216 1.0009812964626774 0.00032327945795884716
# 265 10580.0 1.887037480252041 0.263621187118906 0.2082256898108925 439462.4455707994
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 265 10580.0 1.8849930205015741 0.26333557386952694 1.0000000000000324 0.0004609270308435498
# 270 10570.0 1.8894273167899418 0.26420477083632105 0.2061391392796629 454428.4599344948
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 270 10560.0 1.8842230496772432 0.2637265460025879 1.0000000000000004 -0.0017286879397886423
# 275 10550.0 1.8887724158479908 0.26461388242549044 0.20439207334525947 468516.43466435256
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 275 10550.0 1.8866156748228187 0.2643117265853963 1.0000000000000517 0.000349448638800709
# 280 10540.0 1.8918467497101008 0.2652960569567972 0.2019609185504136 478642.39110930293
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 280 10530.0 1.886572427995234 0.26480767284359025 0.9999999999999075 -0.0015669545640975002
# 285 10520.0 1.8901260346678264 0.26555866530088845 0.2006871807951939 497381.2788085079
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 285 10520.0 1.8878605334557501 0.26524036722600786 0.999999999999987 0.00045162170320622863
# 290 10510.0 1.8924977943791013 0.2661448818991056 0.19855732209439006 509977.1044419611
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 290 10510.0 1.8901842332867687 0.26581952223659294 1.000000000000105 0.00023479471677489983
# 295 10490.0 1.891287889448096 0.26648183259295893 0.1970222764362291 524857.7950999829
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 295 10490.0 1.888922594038914 0.26614856325898867 1.0000000000001155 0.00020347120749875103
# 300 10480.0 1.893013893273751 0.26697953456866425 0.19517243003943285 540016.5422441429
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 300 10480.0 1.8905897902285802 0.26663765334684875 1.0000000000000595 0.00022630506526866156
# 305 10460.0 1.891565025336455 0.2672852811793241 0.19372932176607935 555308.4196473806
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 305 10460.0 1.8890887747120602 0.2669353776150551 0.9999999999998825 0.00027621175372871676
# 310 10450.0 1.8930453301302603 0.2677504293906607 0.19197360090339075 570878.9079385418
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 310 10450.0 1.8905095612357514 0.2673917727861231 0.9999999999999711 0.00033394629660676856
# 315 10440.0 1.8944058255715865 0.26819950674456544 0.19026394368517915 586655.2293078178
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 315 10430.0 1.8887881447994492 0.2676605664016314 0.9999999999999993 -0.001568048173496095
# 320 10420.0 1.8926293386314428 0.2684622971302755 0.18894724270592114 602563.5645554656
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 320 10420.0 1.8899808473952624 0.2680866186882893 0.9999999999999999 0.0004844120517191186
# 325 10410.0 1.8937710247605863 0.26888228539957487 0.1873217488036198 618751.1569179452
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 325 10410.0 1.8910619228871908 0.2684976404274136 1.0000000000000009 0.0006106954805744635
# 330 10390.0 1.8917998840096288 0.26911945823502226 0.1860810178671949 635069.9368021982
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 330 10390.0 1.8890376796744115 0.2687265187172057 1.0000000000000229 0.000446845795991635
# 335 10380.0 1.892456738197875 0.26947225685781706 0.1846752733685187 654127.0922246452
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 335 10380.0 1.8896223918264876 0.2690686662773836 0.9999999999999223 0.0006977954900264649
# 340 10370.0 1.8935779697753954 0.26989192367424303 0.1830251872901784 668472.5979108374
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 340 10360.0 1.8877111491884038 0.26931543124213847 0.9999999999999072 -0.0011506223580823871
# 345 10350.0 1.8912055554486655 0.27007466001559965 0.18195722804513728 686666.7551997133
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 345 10350.0 1.8882613325726223 0.26965420863210693 0.9999999999999967 0.0003407755271211954
# 350 10340.0 1.8918673502813157 0.270430453456617 0.18051753701828982 703896.8488925068
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 350 10340.0 1.8888608481151643 0.2700006930170229 1.0000000000002445 0.0003534552270991753
# 355 10330.0 1.892690463369305 0.27081001749779365 0.17898301814088746 718751.1575939899
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 355 10320.0 1.8866744272051803 0.27021080946708104 1.0000000000000016 -0.0015188012388449579
# 360 10310.0 1.8898428872785955 0.27092712478235076 0.17813377899365668 740203.2004095279
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 360 10310.0 1.8867140125590003 0.27047857054681596 0.9999999999999514 0.0007549798999804125
# 365 10300.0 1.8906121507323548 0.2713005491978711 0.17660434471970737 754099.9398316243
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 365 10300.0 1.887437108716619 0.27084493452181935 1.0000000000000036 0.000216341643650253
# 370 10290.0 1.8909344161443602 0.2716104934015519 0.17529719849237205 772120.0292064387
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 370 10280.0 1.8847605668276497 0.27098704244090677 1.0000000000001639 -0.0012714814257606122
# 375 10270.0 1.8880170790531414 0.2717195758014612 0.17446176536941502 792972.563441467
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 375 10270.0 1.8847126609180487 0.27124401066812653 0.9999999999999983 0.0005597819135374493
# 380 10260.0 1.8880909285285052 0.27199504832114524 0.17326832215918728 812801.357728493
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 380 10260.0 1.8847166268939015 0.2715089523803796 0.9999999999999484 0.00042380036245504016
# 385 10250.0 1.8882044936675126 0.27227678529844834 0.1720436049012321 831482.664073008
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 385 10250.0 1.8847657398254436 0.27178092118802427 0.9999999999999999 0.0002803179917663101
# 390 10230.0 1.885537921660558 0.2724238275548745 0.1710492530267986 847494.3118879197
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 390 10230.0 1.88205618105777 0.2719207832561264 0.999999999999805 0.0008971096662122591
# 395 10220.0 1.8856148259025878 0.2727015091232872 0.1698237334894528 865141.1839669851
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 395 10220.0 1.8820741682848898 0.27218945190864746 0.9999999999999996 0.0005511467295633565
# 400 10210.0 1.8853276738211409 0.2729270324873079 0.16878917179852918 887249.002623777
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 400 10210.0 1.8817099700719209 0.27240332026348446 0.9999999999997781 0.0005250956518239036
# 405 10200.0 1.8851780071729132 0.2731729204683171 0.16766916344931862 906734.480349296
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 405 10190.0 1.8786097809854068 0.2724882928521313 1.0000000000001068 -0.0012321870109133215
# 410 10180.0 1.8821708310520098 0.27327299309440417 0.16682861596686466 924886.3932445183
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 410 10180.0 1.8784385718522811 0.27273110517132765 0.9999999999999702 0.0002245266749696384
# 415 10170.0 1.8819046599025706 0.27350301462740856 0.165755659004786 944765.9947519155
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 415 10170.0 1.8781065023493417 0.2729510166633397 0.9999999999999944 0.00010706815697858474
# 420 10160.0 1.8815811460494463 0.2737251469639821 0.16470573538638916 964850.3601249735
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 420 10160.0 1.8777167914164794 0.27316297559972774 0.9999999999997689 0.0004314151492081919
# 425 10150.0 1.8810316323275682 0.273914807021316 0.163777205800368 988151.7828411754
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 425 10150.0 1.8770884799411378 0.27334060730748755 1.0000000000000124 0.0011747083752737808
# 430 10140.0 1.880852300368157 0.2741587999906705 0.16262370935493564 1004112.1440010754
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 430 10130.0 1.8740106939363699 0.2734312024717647 0.9999999999999238 -0.0010589265074401055
# 435 10120.0 1.8773485750959877 0.27418889274342245 0.1620330428170559 1027788.9612892808
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 435 10120.0 1.8732893657297516 0.2735960406027458 1.0000000000000033 0.0008939273045314167
# 440 10110.0 1.8769795887118905 0.27440615418899605 0.16097193048402206 1045603.3438175683
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 440 10110.0 1.8728657017472898 0.2738047220223847 1.0000000000000506 0.0004543001900856325
# 445 10100.0 1.8763238323897846 0.2745818798431501 0.16007245422760635 1068262.8046567661
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 445 10100.0 1.8721362784174014 0.27396907174369894 0.999999999999975 0.0004077721099804421
# 450 10090.0 1.8756250467363287 0.2747516506457429 0.1591907132736551 1091157.8910248792
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 450 10090.0 1.8713634800976608 0.2741273934306091 1.000000000000755 0.0003255392595065132
# 455 10080.0 1.87502954966591 0.2749369035728499 0.15823704716122708 1111091.767279221
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 455 10080.0 1.8707063673286166 0.2743029923016339 0.9999999999999238 0.0003212048074630047
# 460 10070.0 1.8742448759641859 0.27509475778132225 0.157390808991296 1134426.6997754776
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 460 10060.0 1.8670356114144668 0.27430901068648206 1.000000000000024 -0.0017192415356106494
# 465 10060.0 1.8735583819883002 0.2752673505982139 0.15647470051255855 1154738.8821861662
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 465 10050.0 1.8662935906108398 0.2744728271574596 0.9999999999999992 -0.0012890825447868792
# 470 10040.0 1.8698811317713853 0.2752743459462697 0.15594778044085045 1178432.7344895569
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 470 10040.0 1.8653592078304517 0.27460865140873514 1.0000000000002482 0.00014110873257777712
# 475 10030.0 1.8691805808037893 0.27544556258223135 0.15502367440526535 1197463.5811457168
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 475 10030.0 1.8646028718020509 0.27477098376182685 0.9999999999996323 0.00011560195692084108
# 480 10020.0 1.8683071916914327 0.27559162583229796 0.15420078525979133 1219987.304993947
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 480 10020.0 1.8636605407114175 0.2749062042357037 1.0000000000002154 0.000687048384264699
# 485 10010.0 1.8672726670385218 0.2757141882725223 0.1534745666362633 1246096.0958594785
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 485 10010.0 1.8625437060979309 0.27501592837180017 0.9999999999999952 0.0007430100213241531
# 490 10000.0 1.866388392396807 0.27585920335271946 0.1526420437053411 1267353.5445268764
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 490 10000.0 1.8615965615497485 0.2751509527841586 1.00000000000023 0.0004938327072920856
# 495 9990.0 1.8653484225819887 0.27598147338759016 0.1519041212227756 1292227.0359902773
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 495 9990.0 1.8604802917370322 0.2752612251449723 0.999999999999664 0.00026080335406675204
# 500 9980.0 1.8643341063090657 0.2761077877408602 0.15114117798145185 1315599.0546163872
# abs(LSurface)>10**(-1)
# abs(LSurface)>10**(-1)
# abs(bCorrection-1)>10**(-3)
# abs(bCorrection-1)>10**(-3)
# 500 9980.0 1.859396060947362 0.275376463470189 1.0000000000008868 5.165515366911677e-05
